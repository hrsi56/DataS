# %% [markdown]
# # Pandas - Part B
#
# ## Questions

# %% [markdown]
# © Advanced Analytics, Amir Ben Haim, 2024

# %% [markdown]
# ## Loading CSV's

# %%
# Import necessary Libraries
import pandas as pd

# %% [markdown]
# Replace the `SERVER` with your own instance

# %%
# Read each table to different df
df_od = pd.read_csv('NORTHWND_ord_det.csv')
df_o = pd.read_csv('NORTHWND_ord.csv', encoding='latin1')
df_p = pd.read_csv('NORTHWND_prd.csv', encoding='latin1')
df_cat = pd.read_csv('NORTHWND_cat.csv')
df_cust = pd.read_csv('NORTHWND_cust.csv',encoding='latin1')
df_emp = pd.read_csv('NORTHWND_emp.csv')
df_sup = pd.read_csv('NORTHWND_sup.csv',encoding='latin1')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[7], line 2
#       1 # Read each table to different df
# ----> 2 df_od = pd.read_csv('NORTHWND_ord_det.csv')
#       3 df_o = pd.read_csv('NORTHWND_ord.csv', encoding='latin1')
#       4 df_p = pd.read_csv('NORTHWND_prd.csv', encoding='latin1')
#
# ...

# %% [markdown]
# ## Exercise 1:
# View Customer CompanyName and Country for customer code ALFKI

# %%
df_cust[['CompanyName','Country']][df_cust['CustomerID']=='ALFKI']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 df_cust[['CompanyName','Country']][df_cust['CustomerID']=='ALFKI']
#
# NameError: name 'df_cust' is not defined

# %% [markdown]
# ## Exercise 2:
# View Customer code, full address (country, city, address), and sales contact for customers who live in Berlin, add appropriate aliases as needed

# %%
df_cust['FullAdress']= df_cust['Country']+' - '+df_cust['City'] +' - '+df_cust['Address'] 

df_cust[['CustomerID','ContactName','FullAdress']][df_cust['City']=='Berlin']
# Out:
#   CustomerID   ContactName                        FullAdress
# 0      ALFKI  Maria Anders  Germany - Berlin - Obere Str. 57

# %%
df_p['UnitPrice_aftr20%inc']=df_p['UnitPrice']*1.2
df_p['UnitsRemain']=df_p['UnitsInStock']-df_p['UnitsOnOrder']


df_p[['ProductName','UnitPrice',,'UnitsInStock','UnitsOnOrder','UnitsRemain']]
# Out:
#                         ProductName  UnitPrice  UnitsInStock  UnitsOnOrder  \
# 0                              Chai      18.00            39             0
# 1                             Chang      19.00            17            40
# 2                     Aniseed Syrup      10.00            13            70
# 3      Chef Anton's Cajun Seasoning      22.00            53             0
# 4            Chef Anton's Gumbo Mix      21.35             0             0
# ..                              ...        ...           ...           ...
# 72                       Röd Kaviar      15.00           101             0
# 73                    Longlife Tofu      10.00             4            20
# 74             Rhönbräu Klosterbier       7.75           125             0
# 75                     Lakkalikööri      18.00            57             0
# 76  Original Frankfurter grüne Soße      13.00            32             0
#
#     UnitsRemain
# 0            39
# 1           -23
# ...

# %% [markdown]
# ## Exercise 3:
# View product name and price of Product 6 from the Products table

# %%
df_p[['ProductName','UnitPrice']][5:6]
# Out:
#                     ProductName  UnitPrice
# 5  Grandma's Boysenberry Spread       25.0

# %% [markdown]
# ## Exercise 4:
# View product number, product name, and price from the Products table. Their price is higher than 16 and order the results according to price (ascending order)

# %%
df_p[['ProductID','ProductName','UnitPrice']][df_p['UnitPrice']>16].sort_values(by='UnitPrice', ascending=True)
# Out:
#     ProductID                       ProductName  UnitPrice
# 49         50                  Valkoinen suklaa      16.25
# 65         66         Louisiana Hot Spiced Okra      17.00
# 15         16                           Pavlova      17.45
# 0           1                              Chai      18.00
# 38         39                  Chartreuse verte      18.00
# 34         35                    Steeleye Stout      18.00
# 75         76                      Lakkalikööri      18.00
# 39         40                  Boston Crab Meat      18.40
# 1           2                             Chang      19.00
# 35         36                       Inlagd Sill      19.00
# 43         44                      Gula Malacca      19.45
# 56         57                    Ravioli Angelo      19.50
# 48         49                          Maxilaku      20.00
# 21         22               Gustaf's Knäckebröd      21.00
# 10         11                    Queso Cabrales      21.00
# ...

# %% [markdown]
# ## Exercise 5:
# View from Employees table the full name, date of birth, and the number of the employee he reports to (ReportsTo) for employee number 7

# %%
df_emp['FullName']=df_emp['FirstName']+df_emp['LastName']

df_emp[['FullName','BirthDate','ReportsTo',]][6:7]
# Out:
#      FullName   BirthDate  ReportsTo
# 6  RobertKing  29/05/1960        5.0

# %% [markdown]
# ## Exercise 6:
# View order code and freight from the Orders table for orders that range in freight cost from 33.45 and 65.8, sort the results by freight (descending order)

# %%
df_o[['OrderID','Freight']][(65.8>df_o['Freight']) & (df_o['Freight']>33.45)].sort_values(by='Freight', ascending=False)
# Out:
#      OrderID  Freight
# 746    10994    65.53
# 570    10818    65.48
# 452    10700    65.10
# 521    10769    65.06
# 791    11039    65.00
# ..       ...      ...
# 319    10567    33.97
# 681    10929    33.93
# 768    11016    33.80
# 437    10685    33.75
# 688    10936    33.68
#
# [164 rows x 2 columns]

# %% [markdown]
# ## Exercise 7:
# View all the details from the Products table for products that are not priced between 41 and 92

# %%
df_p[~ ((92>df_p['UnitPrice']) & (df_p['UnitPrice']>41))]
# Out:
#     ProductID                      ProductName  SupplierID  CategoryID  \
# 0           1                             Chai           1           1
# 1           2                            Chang           1           1
# 2           3                    Aniseed Syrup           1           2
# 3           4     Chef Anton's Cajun Seasoning           2           2
# 4           5           Chef Anton's Gumbo Mix           2           2
# ..        ...                              ...         ...         ...
# 72         73                       Röd Kaviar          17           8
# 73         74                    Longlife Tofu           4           7
# 74         75             Rhönbräu Klosterbier          12           1
# 75         76                     Lakkalikööri          23           1
# 76         77  Original Frankfurter grüne Soße          12           2
#
#         QuantityPerUnit  UnitPrice  UnitsInStock  UnitsOnOrder  ReorderLevel  \
# ...

# %% [markdown]
# ## Exercise 8:
# View Order code, Ship city and employee code for orders whose employee code is different from 3, 5 or 8. Sort by employee code (Ascending)

# %%
df_o[['OrderID','ShipCity','EmployeeID']].sort_values(by='EmployeeID')
# Out:
#      OrderID      ShipCity  EmployeeID
# 829    11077   Albuquerque           1
# 139    10387       Stavern           1
# 587    10835        Berlin           1
# 586    10834     Sao Paulo           1
# 145    10393         Boise           1
# ..       ...           ...         ...
# 253    10501      Mannheim           9
# 15     10263          Graz           9
# 581    10829         Cowes           9
# 605    10853      Mannheim           9
# 580    10828  Buenos Aires           9
#
# [830 rows x 3 columns]

# %% [markdown]
# ## Exercise 9:
# View employee code, last name, and Hire date from employees table only for the workers who live in Seattle or Kirkland

# %%
df_emp[['EmployeeID','LastName','HireDate']][(df_emp['City']=='Seattle')|(df_emp['City']=='Kirkland')]
# Out:
#    EmployeeID   LastName    HireDate
# 0           1    Davolio  01/05/1992
# 2           3  Leverling  01/04/1992
# 7           8   Callahan  05/03/1994

# %% [markdown]
# ## Exercise 10:
# View employee number, first and last name for employees from the Employees table. Only for employees which their employee number is equal to 3, 4, 6

# %%
    df_emp[['EmployeeID','FirstName','LastName']][df_emp['EmployeeID'].isin([3,4,6])]
# Out:
#    EmployeeID FirstName   LastName
# 2           3     Janet  Leverling
# 3           4  Margaret    Peacock
# 5           6   Michael     Suyama

# %% [markdown]
# ## Exercise 11:
# View the employee's first name, last name, and date of birth for employees whose employee number is not equal to values 2, 8

# %%
    df_emp[['FirstName','LastName','BirthDate']][~df_emp['EmployeeID'].isin([2,8])]
# Out:
#   FirstName   LastName   BirthDate
# 0     Nancy    Davolio  08/12/1948
# 2     Janet  Leverling  30/08/1963
# 3  Margaret    Peacock  19/09/1937
# 4    Steven   Buchanan  04/03/1955
# 5   Michael     Suyama  02/07/1963
# 6    Robert       King  29/05/1960
# 8      Anne  Dodsworth  27/01/1966

# %% [markdown]
# ## Exercise 12:
# View from the Employees table the last name and city for the employees that has the letter 'w' at the end of their last name.

# %%
df_emp[['LastName','City']][df_emp['LastName'].str.endswith('w')]
# Out:
# Empty DataFrame
# Columns: [LastName, City]
# Index: []

# %% [markdown]
# ## Exercise 13:
# Show employees' first names and region, only for employees that region is Null

# %%
df_emp[['FirstName','Region']][df_emp['Region'].isnull()]
# Out:
#   FirstName Region
# 4    Steven    NaN
# 5   Michael    NaN
# 6    Robert    NaN
# 8      Anne    NaN

# %% [markdown]
# ## Exercise 14:
# Display the names and prices for the 5 most expensive  products

# %%
df_p[['ProductName','UnitPrice']].sort_values(by='UnitPrice',ascending=False)[:5]
# Out:
#                 ProductName  UnitPrice
# 37            Côte de Blaye     263.50
# 28  Thüringer Rostbratwurst     123.79
# 8           Mishi Kobe Niku      97.00
# 19   Sir Rodney's Marmalade      81.00
# 17         Carnarvon Tigers      62.50

# %% [markdown]
# ## Exercise 15:
# Show from the employees table the employee's number, their last name and to whom they report, only for those employees who have a manager. Sort The results according to employee number in ascending order

# %%
df_emp[['EmployeeID','LastName','ReportsTo']][~df_emp['ReportsTo'].isna()].sort_values(by='EmployeeID')
# Out:
#    EmployeeID   LastName  ReportsTo
# 0           1    Davolio        2.0
# 2           3  Leverling        2.0
# 3           4    Peacock        2.0
# 4           5   Buchanan        2.0
# 5           6     Suyama        5.0
# 6           7       King        5.0
# 7           8   Callahan        2.0
# 8           9  Dodsworth        5.0

# %% [markdown]
# ## Exercise 16:
# Show the details for each category, only for categories that has the letter 'e' in their name

# %%
df_cat[df_cat.CategoryName.str.contains('e')]
# Out:
#    CategoryID    CategoryName  \
# 0           1       Beverages
# 1           2      Condiments
# 2           3     Confections
# 4           5  Grains/Cereals
# 5           6    Meat/Poultry
# 6           7         Produce
# 7           8         Seafood
#
#                                          Description
# 0        Soft drinks, coffees, teas, beers, and ales
# 1  Sweet and savory sauces, relishes, spreads, an...
# 2                Desserts, candies, and sweet breads
# 4                Breads, crackers, pasta, and cereal
# 5                                     Prepared meats
# 6                          Dried fruit and bean curd
# 7                                   Seaweed and fish

# %% [markdown]
# ## Exercise 17:
# View from the Products table the product name and category number for products that the letter 'e' is one letter before the end in their names

# %%
df_p[['ProductName','CategoryID']][df_p['ProductName'].str[-2]=='e']
# Out:
#                         ProductName  CategoryID
# 10                   Queso Cabrales           4
# 20              Sir Rodney's Scones           3
# 25              Gumbär Gummibärchen           3
# 40  Jack's New England Clam Chowder           8
# 41    Singaporean Hokkien Fried Mee           5
# 42                      Ipoh Coffee           1
# 46                    Zaanse koeken           3
# 50            Manjimup Dried Apples           7
# 52                    Perth Pasties           6
# 63        Wimmers gute Semmelknödel           5
# 66        Laughing Lumberjack Lager           1
# 69                    Outback Lager           1
# 74             Rhönbräu Klosterbier           1

# %% [markdown]
# ## Exercise 18:
# Show from Customers table customer code, company name, country, phone, and region for The customers who are in countries whose names start with A,B or H, and their region is NULL

# %%
df_cust[['CustomerID','CompanyName','Country','Phone','Region']][(df_cust.Country.str.startswith(('A','B','H')))& df_cust.Region.isnull()]
# Out:
#    CustomerID                 CompanyName    Country              Phone Region
# 11      CACTU  Cactus Comidas para llevar  Argentina       (1) 135-5555    NaN
# 19      ERNSH                Ernst Handel    Austria          7675-3425    NaN
# 49      MAISD                Maison Dewey    Belgium     (02) 201 24 67    NaN
# 53      OCEAN      Océano Atlántico Ltda.  Argentina       (1) 135-5333    NaN
# 58      PICCO            Piccolo und mehr    Austria          6562-9722    NaN
# 63      RANCH               Rancho grande  Argentina       (1) 123-5555    NaN
# 75      SUPRD            Suprêmes délices    Belgium  (071) 23 67 22 20    NaN

# %% [markdown]
# ## Exercise 19:
# Show from Products table, Product number and product name for the products that:
# - Only products that their UnitInStock is not between 19 and 89
# - Their supplier number is 7 or 6
# - Unit price is bigger  than 15

# %%
S = ['ProductID','ProductName']
A =(df_p['UnitsInStock']<19) | (df_p['UnitsInStock']>89)
B =  df_p['SupplierID'].isin([6,7])
C = df_p['UnitPrice'] > 15
df_p[S][ A & B & C ]
# Out:
#     ProductID   ProductName
# 16         17  Alice Mutton
