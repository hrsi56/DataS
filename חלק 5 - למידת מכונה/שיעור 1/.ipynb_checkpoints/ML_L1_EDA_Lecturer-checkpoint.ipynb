# %% [markdown]
# # Exploratory Data Analysis (EDA) With Pandas

# %% [markdown]
# ## EDA methods using Pandas
#
# **[Pandas](http://pandas.pydata.org)** :
# * Provides extensive means for data analysis.
# * Makes it very convenient to load, process, and analyze such tabular data using SQL-like queries.
# * In conjunction with **[`Matplotlib`](https://matplotlib.org/)** and   **[`Seaborn`](https://seaborn.pydata.org/)**, `Pandas` provides a wide range of opportunities for visual analysis of tabular data.
# Main data structures in ``Pandas`` are implemented with theses classes:
#
# * **[Series](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.Series.html)** - one dimensional indexed array of some fixed data type.
# * **[DataFrame](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.html)** - a two-dimensional data structure - where each column contains data of the same type. `DataFrames` are great for representing real data: rows correspond to instances (examples, observations, etc.), and columns correspond to features of these instances.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %% [markdown]
# We’ll demonstrate the main methods in action by analyzing a dataset on the churn rate of telecom operator clients. Let’s read the data (using `read_csv`), and take a look at the first 5 lines using the `head` method:

# %% [markdown]
# <details>
# <summary>Getting inline documentation of specified module, class, function, variables etc.</summary>
#
# In Jupyter notebooks, we can use the `help` function e.g. `help(print())` to access the documentation for a given module, class, function, variable etc.
# The `help` function prints out the doctring of the function and serves an easy and quick reference. To get a non-obtrusive presentation of the topic you want help for use the following syntax `?function`
#
# Try running ``?pd.read_csv`` to see the information you can get for the ``read_csv`` function provided by the ``Pandas`` module
# </details>

# %%
# ?pd.read_csv

# %%
df = pd.read_csv('telecom_churn.csv')
df.head()
# Out:
#   state  account length  area code phone number international plan  \
# 0    KS             128        415     382-4657                 no
# 1    OH             107        415     371-7191                 no
# 2    NJ             137        415     358-1921                 no
# 3    OH              84        408     375-9999                yes
# 4    OK              75        415     330-6626                yes
#
#   voice mail plan  number vmail messages  total day minutes  total day calls  \
# 0             yes                     25              265.1              110
# 1             yes                     26              161.6              123
# 2              no                      0              243.4              114
# 3              no                      0              299.4               71
# 4              no                      0              166.7              113
#
#    total day charge  ...  total eve calls  total eve charge  \
# 0             45.07  ...               99             16.78
# 1             27.47  ...              103             16.62
# 2             41.38  ...              110             10.30
# 3             50.90  ...               88              5.26
# 4             28.34  ...              122             12.61
#
#    total night minutes  total night calls  total night charge  \
# 0                244.7                 91               11.01
# 1                254.4                103               11.45
# 2                162.6                104                7.32
# 3                196.9                 89                8.86
# 4                186.9                121                8.41
#
#    total intl minutes  total intl calls  total intl charge  \
# 0                10.0                 3               2.70
# 1                13.7                 3               3.70
# 2                12.2                 5               3.29
# 3                 6.6                 7               1.78
# 4                10.1                 3               2.73
#
#    customer service calls  churn
# 0                       1  False
# 1                       1  False
# 2                       0  False
# 3                       2  False
# 4                       3  False
#
# [5 rows x 21 columns]

# %% [markdown]
# We can also get a preview of the last five rows in the DataFrame using the `tail` function

# %%
df.tail()
# Out:
#      state  account length  area code phone number international plan  \
# 3328    AZ             192        415     414-4276                 no
# 3329    WV              68        415     370-3271                 no
# 3330    RI              28        510     328-8230                 no
# 3331    CT             184        510     364-6381                yes
# 3332    TN              74        415     400-4344                 no
#
#      voice mail plan  number vmail messages  total day minutes  \
# 3328             yes                     36              156.2
# 3329              no                      0              231.1
# 3330              no                      0              180.8
# 3331              no                      0              213.8
# 3332             yes                     25              234.4
#
#       total day calls  total day charge  ...  total eve calls  \
# 3328               77             26.55  ...              126
# 3329               57             39.29  ...               55
# 3330              109             30.74  ...               58
# 3331              105             36.35  ...               84
# 3332              113             39.85  ...               82
#
#       total eve charge  total night minutes  total night calls  \
# 3328             18.32                279.1                 83
# 3329             13.04                191.3                123
# 3330             24.55                191.9                 91
# 3331             13.57                139.2                137
# 3332             22.60                241.4                 77
#
#       total night charge  total intl minutes  total intl calls  \
# 3328               12.56                 9.9                 6
# 3329                8.61                 9.6                 4
# 3330                8.64                14.1                 6
# 3331                6.26                 5.0                10
# 3332               10.86                13.7                 4
#
#       total intl charge  customer service calls  churn
# 3328               2.67                       2  False
# 3329               2.59                       3  False
# 3330               3.81                       2  False
# 3331               1.35                       2  False
# 3332               3.70                       0  False
#
# [5 rows x 21 columns]

# %% [markdown]
# Let’s have a look at data dimensionality, feature names, and feature types.

# %%
df.shape
# Out:
# (3333, 21)

# %% [markdown]
# From the output, we can see that the table contains 3333 rows and 21 columns.
#
# Is the index a column?
#
# Now let’s try printing out column names using `columns`:

# %%
df.columns
# Out:
# Index(['state', 'account length', 'area code', 'phone number',
#        'international plan', 'voice mail plan', 'number vmail messages',
#        'total day minutes', 'total day calls', 'total day charge',
#        'total eve minutes', 'total eve calls', 'total eve charge',
#        'total night minutes', 'total night calls', 'total night charge',
#        'total intl minutes', 'total intl calls', 'total intl charge',
#        'customer service calls', 'churn'],
#       dtype='object')

# %% [markdown]
# We can use the `info()` method to output some general information about the dataframe:

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3333 entries, 0 to 3332
# Data columns (total 21 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   state                   3333 non-null   object
#  1   account length          3333 non-null   int64
#  2   area code               3333 non-null   int64
#  3   phone number            3333 non-null   object
#  4   international plan      3333 non-null   object
#  5   voice mail plan         3333 non-null   object
#  6   number vmail messages   3333 non-null   int64
#  7   total day minutes       3333 non-null   float64
#  8   total day calls         3333 non-null   int64
#  9   total day charge        3333 non-null   float64
#  10  total eve minutes       3333 non-null   float64
#  11  total eve calls         3333 non-null   int64
#  12  total eve charge        3333 non-null   float64
#  13  total night minutes     3333 non-null   float64
#  14  total night calls       3333 non-null   int64
#  15  total night charge      3333 non-null   float64
#  16  total intl minutes      3333 non-null   float64
#  17  total intl calls        3333 non-null   int64
#  18  total intl charge       3333 non-null   float64
#  19  customer service calls  3333 non-null   int64
#  20  churn                   3333 non-null   bool
# dtypes: bool(1), float64(8), int64(8), object(4)
# memory usage: 524.2+ KB

# %% [markdown]
# `bool`, `int64`, `float64` and `object` are the data types of our features. We see that one feature is logical (`bool`), 4 features are of type `object`, and 16 features are numeric. With this same method, we can easily see if there are any missing values. Here, there are none because each column contains 3333 observations, the same number of rows we saw before with `shape`.
#
# We can **change the column type** with the `astype` method. Let’s apply this method to the `Churn` feature to convert it into `int64`:

# %%
df['churn'] = df['churn'].astype('int64')

# %%
df.churn
# Out:
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0
#        ..
# 3328    0
# 3329    0
# 3330    0
# 3331    0
# 3332    0
# Name: churn, Length: 3333, dtype: int64

# %% [markdown]
# The area code is not really a numerical value but more of a numerical representation, let's convert this column type to object.

# %%
df['area code'] = df['area code'].astype('object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3333 entries, 0 to 3332
# Data columns (total 21 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   state                   3333 non-null   object
#  1   account length          3333 non-null   int64
#  2   area code               3333 non-null   object
#  3   phone number            3333 non-null   object
#  4   international plan      3333 non-null   object
#  5   voice mail plan         3333 non-null   object
#  6   number vmail messages   3333 non-null   int64
#  7   total day minutes       3333 non-null   float64
#  8   total day calls         3333 non-null   int64
#  9   total day charge        3333 non-null   float64
#  10  total eve minutes       3333 non-null   float64
#  11  total eve calls         3333 non-null   int64
#  12  total eve charge        3333 non-null   float64
#  13  total night minutes     3333 non-null   float64
#  14  total night calls       3333 non-null   int64
#  15  total night charge      3333 non-null   float64
#  16  total intl minutes      3333 non-null   float64
#  17  total intl calls        3333 non-null   int64
#  18  total intl charge       3333 non-null   float64
#  19  customer service calls  3333 non-null   int64
#  20  churn                   3333 non-null   int64
# dtypes: float64(8), int64(8), object(5)
# memory usage: 546.9+ KB

# %% [markdown]
# The `describe` method shows basic statistical characteristics of each numerical feature (`int64` and `float64` types): number of non-missing values, mean, standard deviation, range, median, 0.25 and 0.75 quartiles.

# %%
df.describe()
# Out:
#        account length  number vmail messages  total day minutes  \
# count     3333.000000            3333.000000        3333.000000
# mean       101.064806               8.099010         179.775098
# std         39.822106              13.688365          54.467389
# min          1.000000               0.000000           0.000000
# 25%         74.000000               0.000000         143.700000
# 50%        101.000000               0.000000         179.400000
# 75%        127.000000              20.000000         216.400000
# max        243.000000              51.000000         350.800000
#
#        total day calls  total day charge  total eve minutes  total eve calls  \
# count      3333.000000       3333.000000        3333.000000      3333.000000
# mean        100.435644         30.562307         200.980348       100.114311
# std          20.069084          9.259435          50.713844        19.922625
# min           0.000000          0.000000           0.000000         0.000000
# 25%          87.000000         24.430000         166.600000        87.000000
# 50%         101.000000         30.500000         201.400000       100.000000
# 75%         114.000000         36.790000         235.300000       114.000000
# max         165.000000         59.640000         363.700000       170.000000
#
#        total eve charge  total night minutes  total night calls  \
# count       3333.000000          3333.000000        3333.000000
# mean          17.083540           200.872037         100.107711
# std            4.310668            50.573847          19.568609
# min            0.000000            23.200000          33.000000
# 25%           14.160000           167.000000          87.000000
# 50%           17.120000           201.200000         100.000000
# 75%           20.000000           235.300000         113.000000
# max           30.910000           395.000000         175.000000
#
#        total night charge  total intl minutes  total intl calls  \
# count         3333.000000         3333.000000       3333.000000
# mean             9.039325           10.237294          4.479448
# std              2.275873            2.791840          2.461214
# min              1.040000            0.000000          0.000000
# 25%              7.520000            8.500000          3.000000
# 50%              9.050000           10.300000          4.000000
# 75%             10.590000           12.100000          6.000000
# max             17.770000           20.000000         20.000000
#
#        total intl charge  customer service calls        churn
# count        3333.000000             3333.000000  3333.000000
# mean            2.764581                1.562856     0.144914
# std             0.753773                1.315491     0.352067
# min             0.000000                0.000000     0.000000
# 25%             2.300000                1.000000     0.000000
# 50%             2.780000                1.000000     0.000000
# 75%             3.270000                2.000000     0.000000
# max             5.400000                9.000000     1.000000

# %% [markdown]
# Observation:
# * mean and median are significantly different in the *number vmail messages* series &rightarrow; the distribution is skewed and the median is a likely better measure than the mean

# %% [markdown]
# Now let's do some plotting to learn more about our data

# %%
df.plot.box(figsize=(10,5), rot=90, fontsize=12)
# Out:
# <Axes: >

# %%
df[df['churn'] == 0].plot.box(figsize=(10,5), rot=90, fontsize=12)
# Out:
# <Axes: >

# %%
df[df['churn'] == 1].plot.box(figsize=(10,5), rot=90, fontsize=12)
# Out:
# <Axes: >

# %% [markdown]
# ### Data types

# %% [markdown]
# **Categorial data** (type `object` and `bool`)
#
# * Can be analyzed using value_counts()
# * Best visualized by Bar plots

# %% [markdown]
# In order to see statistics on non-numerical features, one has to explicitly indicate data types of interest in the `include` parameter.

# %%
df.describe(include=['object', 'bool'])
# Out:
#        state  area code phone number international plan voice mail plan
# count   3333       3333         3333               3333            3333
# unique    51          3         3333                  2               2
# top       WV        415     400-4344                 no              no
# freq     106       1655            1               3010            2411

# %% [markdown]
# Let’s have a look at the distribution of `Churn`:

# %%
df['churn'].value_counts()
# Out:
# churn
# 0    2850
# 1     483
# Name: count, dtype: int64

# %%
df['churn'].value_counts()[0]/(len(df))
# Out:
# np.float64(0.8550855085508551)

# %% [markdown]
# 2850 users out of 3333 are *loyal*; their `Churn` value is `0`.
#
# To calculate fractions, pass `normalize=True` to the `value_counts` function.

# %%
df['churn'].value_counts(normalize=True)
# Out:
# churn
# 0    0.855086
# 1    0.144914
# Name: proportion, dtype: float64

# %% [markdown]
# Let's visualize `area code` using bar plot

# %%
df['area code'].value_counts(normalize=True).plot(kind = 'bar', title = "area code",figsize=(7,5))
# Out:
# <Axes: title={'center': 'area code'}, xlabel='area code'>

# %% [markdown]
# **Numerical data**
# * Best visualized by box plot or distribution plot (histogram)

# %%
df['account length'].plot.hist(figsize=(7,7))
# Out:
# <Axes: ylabel='Frequency'>

# %%
# univariate
df['total eve calls'].plot.box(figsize=(8,5))

# bivariate
df.boxplot(column='total eve calls', by='churn')
# Out:
# <Axes: title={'center': 'total eve calls'}, xlabel='churn'>

# %% [markdown]
# **`datatime` data type**
#
#
# Let's generate some fake customer signup dates so we can work with the `datetime` data type in Pandas

# %%
import random
df['date joined'] = random.sample(pd.date_range('1995-01-01', '2019-01-01').tolist(),df.shape[0])

# %%
df.head()
# Out:
#   state  account length area code phone number international plan  \
# 0    KS             128       415     382-4657                 no
# 1    OH             107       415     371-7191                 no
# 2    NJ             137       415     358-1921                 no
# 3    OH              84       408     375-9999                yes
# 4    OK              75       415     330-6626                yes
#
#   voice mail plan  number vmail messages  total day minutes  total day calls  \
# 0             yes                     25              265.1              110
# 1             yes                     26              161.6              123
# 2              no                      0              243.4              114
# 3              no                      0              299.4               71
# 4              no                      0              166.7              113
#
#    total day charge  ...  total eve charge  total night minutes  \
# 0             45.07  ...             16.78                244.7
# 1             27.47  ...             16.62                254.4
# 2             41.38  ...             10.30                162.6
# 3             50.90  ...              5.26                196.9
# 4             28.34  ...             12.61                186.9
#
#    total night calls  total night charge  total intl minutes  \
# 0                 91               11.01                10.0
# 1                103               11.45                13.7
# 2                104                7.32                12.2
# 3                 89                8.86                 6.6
# 4                121                8.41                10.1
#
#    total intl calls  total intl charge  customer service calls  churn  \
# 0                 3               2.70                       1      0
# 1                 3               3.70                       1      0
# 2                 5               3.29                       0      0
# 3                 7               1.78                       2      0
# 4                 3               2.73                       3      0
#
#    date joined
# 0   2009-03-23
# 1   1997-04-15
# 2   2007-05-14
# 3   1999-01-03
# 4   2010-08-27
#
# [5 rows x 22 columns]

# %% [markdown]
# Now let's calcualte how much time had passed since the customer joined the service

# %%
df['days since joined'] = (pd.to_datetime('today') - df['date joined']).dt.days

# %%
df.head()
# Out:
#   state  account length area code phone number international plan  \
# 0    KS             128       415     382-4657                 no
# 1    OH             107       415     371-7191                 no
# 2    NJ             137       415     358-1921                 no
# 3    OH              84       408     375-9999                yes
# 4    OK              75       415     330-6626                yes
#
#   voice mail plan  number vmail messages  total day minutes  total day calls  \
# 0             yes                     25              265.1              110
# 1             yes                     26              161.6              123
# 2              no                      0              243.4              114
# 3              no                      0              299.4               71
# 4              no                      0              166.7              113
#
#    total day charge  ...  total night minutes  total night calls  \
# 0             45.07  ...                244.7                 91
# 1             27.47  ...                254.4                103
# 2             41.38  ...                162.6                104
# 3             50.90  ...                196.9                 89
# 4             28.34  ...                186.9                121
#
#    total night charge  total intl minutes  total intl calls  \
# 0               11.01                10.0                 3
# 1               11.45                13.7                 3
# 2                7.32                12.2                 5
# 3                8.86                 6.6                 7
# 4                8.41                10.1                 3
#
#    total intl charge  customer service calls  churn  date joined  \
# 0               2.70                       1      0   2009-03-23
# 1               3.70                       1      0   1997-04-15
# 2               3.29                       0      0   2007-05-14
# 3               1.78                       2      0   1999-01-03
# 4               2.73                       3      0   2010-08-27
#
#    days since joined
# 0               5852
# 1              10212
# 2               6531
# 3               9584
# 4               5330
#
# [5 rows x 23 columns]

# %% [markdown]
# When did the first customer join? when was the latest time we signed up a customer?

# %%
df['date joined'].min(), df['date joined'].max()
# Out:
# (Timestamp('1995-01-04 00:00:00'), Timestamp('2018-12-29 00:00:00'))

# %% [markdown]
# Find the date joined day of week distribution

# %%
pd.to_datetime(df['date joined']).dt.day_name().value_counts(normalize=True)
# Out:
# date joined
# Saturday     0.147915
# Wednesday    0.145515
# Monday       0.143114
# Friday       0.141914
# Tuesday      0.141614
# Thursday     0.140114
# Sunday       0.139814
# Name: proportion, dtype: float64

# %%
pd.to_datetime(df['date joined']).dt.day_name().value_counts(normalize=True).plot.bar()
# Out:
# <Axes: xlabel='date joined'>

# %% [markdown]
# ### Sorting
#
# A DataFrame can be sorted by the value of one of the variables (i.e columns). For example, we can sort by *Total day charge* (use `ascending=False` to sort in descending order):

# %%
df.sort_values(by='total day charge', ascending=False).head()
# Out:
#      state  account length area code phone number international plan  \
# 365     CO             154       415     343-5709                 no
# 985     NY              64       415     345-9140                yes
# 2594    OH             115       510     348-1163                yes
# 156     OH              83       415     370-9116                 no
# 605     MO             112       415     373-2053                 no
#
#      voice mail plan  number vmail messages  total day minutes  \
# 365               no                      0              350.8
# 985               no                      0              346.8
# 2594              no                      0              345.3
# 156               no                      0              337.4
# 605               no                      0              335.5
#
#       total day calls  total day charge  ...  total night minutes  \
# 365                75             59.64  ...                253.9
# 985                55             58.96  ...                275.4
# 2594               81             58.70  ...                217.5
# 156               120             57.36  ...                153.9
# 605                77             57.04  ...                265.0
#
#       total night calls  total night charge  total intl minutes  \
# 365                 100               11.43                10.1
# 985                 102               12.39                13.3
# 2594                107                9.79                11.8
# 156                 114                6.93                15.8
# 605                 132               11.93                12.7
#
#       total intl calls  total intl charge  customer service calls  churn  \
# 365                  9               2.73                       1      1
# 985                  9               3.59                       1      1
# 2594                 8               3.19                       1      1
# 156                  7               4.27                       0      1
# 605                  8               3.43                       2      1
#
#       date joined  days since joined
# 365    2017-03-10               2943
# 985    2015-11-26               3413
# 2594   1997-11-08              10005
# 156    1999-06-17               9419
# 605    2016-11-17               3056
#
# [5 rows x 23 columns]

# %% [markdown]
# We can also sort by multiple columns:

# %%
df.sort_values(by=['churn', 'total day charge'],
        ascending=[True, False]).head()
# Out:
#      state  account length area code phone number international plan  \
# 688     MN              13       510     338-7120                 no
# 2259    NC             210       415     363-7802                 no
# 534     LA              67       510     373-6784                 no
# 575     SD             114       415     351-7369                 no
# 2858    AL             141       510     388-8583                 no
#
#      voice mail plan  number vmail messages  total day minutes  \
# 688              yes                     21              315.6
# 2259             yes                     31              313.8
# 534               no                      0              310.4
# 575              yes                     36              309.9
# 2858             yes                     28              308.0
#
#       total day calls  total day charge  ...  total night minutes  \
# 688               105             53.65  ...                260.1
# 2259               87             53.35  ...                192.7
# 534                97             52.77  ...                246.5
# 575                90             52.68  ...                183.5
# 2858              123             52.36  ...                152.9
#
#       total night calls  total night charge  total intl minutes  \
# 688                 123               11.70                12.1
# 2259                 97                8.67                10.1
# 534                  99               11.09                 9.2
# 575                 105                8.26                14.2
# 2858                103                6.88                 7.4
#
#       total intl calls  total intl charge  customer service calls  churn  \
# 688                  3               3.27                       3      0
# 2259                 7               2.73                       3      0
# 534                 10               2.48                       4      0
# 575                  2               3.83                       1      0
# 2858                 3               2.00                       1      0
#
#       date joined  days since joined
# 688    2000-12-31               8856
# 2259   2015-08-01               3530
# 534    2012-07-12               4645
# 575    2017-02-03               2978
# 2858   1995-09-29              10776
#
# [5 rows x 23 columns]

# %% [markdown]
# We can also sort by the ``DataFrame`` index using the `sort_index` function

# %%
df.sort_index(ascending=False).head(10)
# Out:
#      state  account length area code phone number international plan  \
# 3332    TN              74       415     400-4344                 no
# 3331    CT             184       510     364-6381                yes
# 3330    RI              28       510     328-8230                 no
# 3329    WV              68       415     370-3271                 no
# 3328    AZ             192       415     414-4276                 no
# 3327    SC              79       415     348-3830                 no
# 3326    OH              96       415     347-6812                 no
# 3325    OH              78       408     368-8555                 no
# 3324    WV             159       415     377-1164                 no
# 3323    IN             117       415     362-5899                 no
#
#      voice mail plan  number vmail messages  total day minutes  \
# 3332             yes                     25              234.4
# 3331              no                      0              213.8
# 3330              no                      0              180.8
# 3329              no                      0              231.1
# 3328             yes                     36              156.2
# 3327              no                      0              134.7
# 3326              no                      0              106.6
# 3325              no                      0              193.4
# 3324              no                      0              169.8
# 3323              no                      0              118.4
#
#       total day calls  total day charge  ...  total night minutes  \
# 3332              113             39.85  ...                241.4
# 3331              105             36.35  ...                139.2
# 3330              109             30.74  ...                191.9
# 3329               57             39.29  ...                191.3
# 3328               77             26.55  ...                279.1
# 3327               98             22.90  ...                221.4
# 3326              128             18.12  ...                178.9
# 3325               99             32.88  ...                243.3
# 3324              114             28.87  ...                193.7
# 3323              126             20.13  ...                227.0
#
#       total night calls  total night charge  total intl minutes  \
# 3332                 77               10.86                13.7
# 3331                137                6.26                 5.0
# 3330                 91                8.64                14.1
# 3329                123                8.61                 9.6
# 3328                 83               12.56                 9.9
# 3327                128                9.96                11.8
# 3326                 92                8.05                14.9
# 3325                109               10.95                 9.3
# 3324                 82                8.72                11.6
# 3323                 56               10.22                13.6
#
#       total intl calls  total intl charge  customer service calls  churn  \
# 3332                 4               3.70                       0      0
# 3331                10               1.35                       2      0
# 3330                 6               3.81                       2      0
# 3329                 4               2.59                       3      0
# 3328                 6               2.67                       2      0
# 3327                 5               3.19                       2      0
# 3326                 7               4.02                       1      0
# 3325                 4               2.51                       2      0
# 3324                 4               3.13                       1      0
# 3323                 3               3.67                       5      1
#
#       date joined  days since joined
# 3332   2006-09-12               6775
# 3331   1998-05-27               9805
# 3330   1996-12-22              10326
# 3329   1995-09-28              10777
# 3328   2006-04-07               6933
# 3327   2008-03-16               6224
# 3326   2016-08-23               3142
# 3325   2018-04-10               2547
# 3324   2007-03-20               6586
# 3323   2008-12-19               5946
#
# [10 rows x 23 columns]

# %% [markdown]
# To get a single column, you can use a `DataFrame['Name']` construction.

# %% [markdown]
# ####Question 1
# Let's use this to answer a question about that column alone:
#
# **what is the proportion of churned users in our dataframe?**

# %% [markdown]
# ####Answer 1

# %%
df['churn'].mean()
# Out:
# 0.14491449144914492

# %% [markdown]
# 14.5% is actually quite bad for a company; such a churn rate can make the company go bankrupt.
#
# **Boolean indexing** with one column is also very convenient. The syntax is `df[P(df['Name'])]`, where `P` is some logical condition that is checked for each element of the `Name` column. The result of such indexing is the DataFrame consisting only of rows that satisfy the `P` condition on the `Name` column.

# %% [markdown]
# ####Question 2
# Let’s use it to answer the question:
#
# **What are the average values of numerical features for churned users?**

# %% [markdown]
# ####Answer 2

# %%
df[df['churn'] == 1].mean(numeric_only=True)
# Out:
# account length             102.664596
# number vmail messages        5.115942
# total day minutes          206.914079
# total day calls            101.335404
# total day charge            35.175921
# total eve minutes          212.410145
# total eve calls            100.561077
# total eve charge            18.054969
# total night minutes        205.231677
# total night calls          100.399586
# total night charge           9.235528
# total intl minutes          10.700000
# total intl calls             4.163561
# total intl charge            2.889545
# customer service calls       2.229814
# churn                        1.000000
# days since joined         6580.590062
# dtype: float64

# %% [markdown]
# ####Question 3
#
# **How much time (on average) do churned users spend on the phone during daytime?**
#
# Relevant column name: `total day minutes`

# %% [markdown]
# ####Answer 3

# %%
df[df['churn'] == 1]['total day minutes'].mean(numeric_only=True)
# Out:
# 206.91407867494823

# %% [markdown]
# ####Question 4
#
# **What is the maximum length of international calls among loyal users (`Churn == 0`) who do not have an international plan?**
#
# Relevant columns names: `international plan`,` total intl minutes`

# %% [markdown]
# ####Answer 4

# %%
df[(df['churn'] == 0) & (df['international plan'] == 'no')]['total intl minutes'].max()
# Out:
# 18.9

# %% [markdown]
# ####Indexing using `loc`
#
#
# DataFrames can be indexed by column name (label) or row name (index) or by the serial number of a row. The `loc` method is used for **indexing by name**, while `iloc()` is used for **indexing by number**.
#
# In the first case below, we say **"give us the values of the rows with index from 0 to 5 (inclusive) and columns labeled from State to Area code (inclusive)"**.
#
# In the second case, we say **"give us the values of the first five rows in the first three columns"** (as in a typical Python slice: the maximal value is not included).

# %%
df.loc[0:5, 'state':'area code']
# Out:
#   state  account length area code
# 0    KS             128       415
# 1    OH             107       415
# 2    NJ             137       415
# 3    OH              84       408
# 4    OK              75       415
# 5    AL             118       510

# %%
df.iloc[0:5, 0:3]
# Out:
#   state  account length area code
# 0    KS             128       415
# 1    OH             107       415
# 2    NJ             137       415
# 3    OH              84       408
# 4    OK              75       415

# %% [markdown]
# If we need the first or the last line of the data frame, we can use the `df[:1]` or `df[-1:]` construct:

# %%
df[:1] # first line
# Out:
#   state  account length area code phone number international plan  \
# 0    KS             128       415     382-4657                 no
#
#   voice mail plan  number vmail messages  total day minutes  total day calls  \
# 0             yes                     25              265.1              110
#
#    total day charge  ...  total night minutes  total night calls  \
# 0             45.07  ...                244.7                 91
#
#    total night charge  total intl minutes  total intl calls  \
# 0               11.01                10.0                 3
#
#    total intl charge  customer service calls  churn  date joined  \
# 0                2.7                       1      0   2000-08-06
#
#    days since joined
# 0               8872
#
# [1 rows x 23 columns]

# %%
df[-1:] # last line
# Out:
#      state  account length area code phone number international plan  \
# 3332    TN              74       415     400-4344                 no
#
#      voice mail plan  number vmail messages  total day minutes  \
# 3332             yes                     25              234.4
#
#       total day calls  total day charge  ...  total night minutes  \
# 3332              113             39.85  ...                241.4
#
#       total night calls  total night charge  total intl minutes  \
# 3332                 77               10.86                13.7
#
#       total intl calls  total intl charge  customer service calls  churn  \
# 3332                 4                3.7                       0      0
#
#       date joined  days since joined
# 3332   1998-06-03               9667
#
# [1 rows x 23 columns]

# %% [markdown]
# ### Applying Functions to Cells, Columns and Rows
#
# **To apply functions to each column, use `apply()`:**

# %%
df.apply(np.max)
# Out:
# state                                      WY
# account length                            243
# area code                                 510
# phone number                         422-9964
# international plan                        yes
# voice mail plan                           yes
# number vmail messages                      51
# total day minutes                       350.8
# total day calls                           165
# total day charge                        59.64
# total eve minutes                       363.7
# total eve calls                           170
# total eve charge                        30.91
# total night minutes                     395.0
# total night calls                         175
# total night charge                      17.77
# total intl minutes                       20.0
# total intl calls                           20
# total intl charge                         5.4
# customer service calls                      9
# churn                                       1
# date joined               2019-01-01 00:00:00
# days since joined                       10912
# dtype: object

# %% [markdown]
# The `apply` method can also be used to apply a function to each row. To do this, specify `axis=1` or aplly on a specific column. Lambda functions are very convenient in such scenarios. For example, if we need to select all states starting with W, we can do it like this:

# %%
df[df['state'].apply(lambda state: state[0] == 'W')].head()
# Out:
#    state  account length area code phone number international plan  \
# 9     WV             141       415     330-8173                yes
# 26    WY              57       408     357-3817                 no
# 44    WI              64       510     352-1237                 no
# 49    WY              97       415     405-7146                 no
# 54    WY              87       415     353-3759                 no
#
#    voice mail plan  number vmail messages  total day minutes  total day calls  \
# 9              yes                     37              258.6               84
# 26             yes                     39              213.0              115
# 44              no                      0              154.0               67
# 49             yes                     24              133.2              135
# 54              no                      0              151.0               83
#
#     total day charge  ...  total night minutes  total night calls  \
# 9              43.96  ...                326.4                 97
# 26             36.21  ...                182.7                115
# 44             26.18  ...                265.3                 86
# 49             22.64  ...                 70.6                 79
# 54             25.67  ...                203.9                127
#
#     total night charge  total intl minutes  total intl calls  \
# 9                14.69                11.2                 5
# 26                8.22                 9.5                 3
# 44               11.94                 3.5                 3
# 49                3.18                11.0                 3
# 54                9.18                 9.7                 3
#
#     total intl charge  customer service calls  churn  date joined  \
# 9                3.02                       0      0   1999-08-18
# 26               2.57                       0      0   2001-06-15
# 44               0.95                       1      0   2003-06-25
# 49               2.97                       1      0   2001-03-02
# 54               2.62                       5      1   2012-10-02
#
#     days since joined
# 9                9226
# 26               8559
# 44               7819
# 49               8664
# 54               4432
#
# [5 rows x 23 columns]

# %% [markdown]
# Let's define a lambda function that removes the hyphen(-) from the phone numbers and apply it over the entire phone-number column

# %%
df['phone number'] = df['phone number'].apply(lambda x: x.replace('-',''))

# %%
df['phone number']
# Out:
# 0       3824657
# 1       3717191
# 2       3581921
# 3       3759999
# 4       3306626
#          ...
# 3328    4144276
# 3329    3703271
# 3330    3288230
# 3331    3646381
# 3332    4004344
# Name: phone number, Length: 3333, dtype: object

# %% [markdown]
# Let's normalize the values of an entire row  by applying a *max* normalization using the `normalize` function provided by sklearn

# %%
from sklearn.preprocessing import normalize
# apply on a row
df.select_dtypes(include=['int64']).apply(lambda x: normalize([x], norm="max"), axis=1)
# Out:
# 0       [[0.014427412082957619, 0.00281785392245266, 0...
# 1       [[0.01340516161363067, 0.003257328990228013, 0...
# 2       [[0.026700448255700643, 0.0, 0.022217891249269...
# 3       [[0.014153327716933445, 0.0, 0.011962931760741...
# 4       [[0.007828810020876827, 0.0, 0.011795407098121...
#                               ...
# 3328    [[0.022101991481524117, 0.004144123402785772, ...
# 3329    [[0.025101513473606497, 0.0, 0.021040974529346...
# 3330    [[0.003118387348257044, 0.0, 0.012139436462857...
# 3331    [[0.03669724770642202, 0.0, 0.0209413641802951...
# 3332    [[0.007654908451432709, 0.002586117720078618, ...
# Length: 3333, dtype: object

# %% [markdown]
# The `map` method can be used to **replace values in a column** by passing a dictionary of the form `{old_value: new_value}` as its argument:

# %%
df['international plan'].unique()
# Out:
# array(['no', 'yes'], dtype=object)

# %%
d = {'no' : False, 'yes' : True}
df['international plan'] = df['international plan'].map(d)
df['international plan'].unique()
# Out:
# array([False,  True])

# %% [markdown]
# And it can also be done with `np.where()` function

# %%
df['voice mail plan'] = np.where(df['voice mail plan']==True,1,0)
df['voice mail plan'].unique()
# Out:
# array([1, 0])

# %%
df['voice mail plan'].dtype
# Out:
# dtype('int64')

# %% [markdown]
# ### Grouping

# %% [markdown]
# In general, grouping data in Pandas works as follows:

# %% [markdown]
# ```python
# df.groupby(by=grouping_columns)[columns_to_show].function()
# ```

# %% [markdown]
# 1. First, the `groupby` method divides the `grouping_columns` by their values. They become a new index in the resulting dataframe.
# 2. Then, columns of interest are selected (`columns_to_show`). If `columns_to_show` is not included, all non groupby clauses will be included.
# 3. Finally, one or several functions are applied to the obtained groups per selected columns.
#
# Here is an example where we group the data according to the values of the `Churn` variable and display statistics of three columns in each group:

# %%
columns_to_show = ['total day minutes', 'total eve minutes',
                   'total night minutes']

df.groupby(['churn'])[columns_to_show].describe(percentiles=[0.25, .95])
# Out:
#       total day minutes                                                       \
#                   count        mean        std  min      25%    50%      95%
# churn
# 0                2850.0  175.175754  50.181655  0.0  142.825  177.2  254.155
# 1                 483.0  206.914079  68.997792  0.0  153.250  217.6  311.660
#
#              total eve minutes              ...                 \
#          max             count        mean  ...     95%    max
# churn                                       ...
# 0      315.6            2850.0  199.043298  ...  281.10  361.8
# 1      350.8             483.0  212.410145  ...  300.81  363.7
#
#       total night minutes                                               \
#                     count        mean        std   min     25%     50%
# churn
# 0                  2850.0  200.133193  51.105032  23.2  165.90  200.25
# 1                   483.0  205.231677  47.132825  47.4  171.25  204.80
#
#
#           95%    max
# churn
# 0      282.71  395.0
# 1      283.32  354.9
#
# [2 rows x 24 columns]

# %% [markdown]
# ### Summary tables
#
# Suppose we want to see how the observations in our sample are distributed in the context of two variables - `Churn` and `International plan`. To do so, we can build a **contingency table** using the `crosstab` method:

# %%
pd.crosstab(df['churn'], df['international plan'], margins=True)
# Out:
# international plan  False  True   All
# churn
# 0                    2664   186  2850
# 1                     346   137   483
# All                  3010   323  3333

# %%
pd.crosstab(df['churn'], df['voice mail plan'], normalize=True, margins=True)
# Out:
# voice mail plan         0         1       All
# churn
# 0                0.602460  0.252625  0.855086
# 1                0.120912  0.024002  0.144914
# All              0.723372  0.276628  1.000000

# %% [markdown]
# We can see that most of the users are loyal and do not use additional services (International Plan/Voice mail).
#
# This will resemble **pivot tables** to those familiar with Excel. And, of course, pivot tables are implemented in Pandas: the `pivot_table` method takes the following parameters:
#
# * `values` – a list of variables to calculate statistics for,
# * `index` – a list of variables to group data by,
# * `aggfunc` – what statistics we need to calculate for groups, ex. sum, mean, maximum, minimum or something else.
#
# Let’s take a look at the average number of day, evening, and night calls by area code:

# %%
df.pivot_table(['total day calls', 'total eve calls', 'total night calls'],
               ['area code', 'churn'], aggfunc='mean')
# Out:
#                  total day calls  total eve calls  total night calls
# area code churn
# 408       0           100.101955       100.019553          99.276536
#           1           102.811475        98.434426          97.647541
# 415       0           100.606765       100.391121         100.294574
#           1           100.394068       101.182203         101.021186
# 510       0            99.822378        99.358042         100.372028
#           1           101.672000       101.464000         101.912000

# %% [markdown]
# ### DataFrame transformations

# %% [markdown]
# #### Adding rows and columns
#
# Like many other things in Pandas, adding columns to a DataFrame is doable in many ways.
#
# For example, if we want to calculate the total number of calls for all users

# %% [markdown]
# # Let’s add a `total_calls` column
#
# Relevant columns: `total day calls`, `total eve calls`, `total night calls`, `total intl calls`

# %% [markdown]
# create the `total_calls` Series and paste it into the DataFrame

# %%
total_calls = df['total day calls'] + df['total eve calls'] + \
              df['total night calls'] + df['total intl calls']
df.insert(loc=len(df.columns), column='total calls', value=total_calls)
# loc parameter is the number of columns after which to insert the Series object
# we set it to len(df.columns) to paste it at the very end of the dataframe
df.head()
# Out:
#   state  account length area code phone number  international plan  \
# 0    KS             128       415      3824657               False
# 1    OH             107       415      3717191               False
# 2    NJ             137       415      3581921               False
# 3    OH              84       408      3759999                True
# 4    OK              75       415      3306626                True
#
#    voice mail plan  number vmail messages  total day minutes  total day calls  \
# 0                1                     25              265.1              110
# 1                1                     26              161.6              123
# 2                0                      0              243.4              114
# 3                0                      0              299.4               71
# 4                0                      0              166.7              113
#
#    total day charge  ...  total night calls  total night charge  \
# 0             45.07  ...                 91               11.01
# 1             27.47  ...                103               11.45
# 2             41.38  ...                104                7.32
# 3             50.90  ...                 89                8.86
# 4             28.34  ...                121                8.41
#
#    total intl minutes  total intl calls  total intl charge  \
# 0                10.0                 3               2.70
# 1                13.7                 3               3.70
# 2                12.2                 5               3.29
# 3                 6.6                 7               1.78
# 4                10.1                 3               2.73
#
#    customer service calls  churn  date joined  days since joined  total calls
# 0                       1      0   2000-08-06               8872          303
# 1                       1      0   2003-01-13               7982          332
# 2                       0      0   2010-11-03               5131          333
# 3                       2      0   2008-08-21               5935          255
# 4                       3      0   1998-08-29               9580          359
#
# [5 rows x 24 columns]

# %% [markdown]
# ####Question 1
#
# **Let’s add a `total charge` column**
#
# Relevant columns: `total day charge`, `total eve charge`, `total night charge`, `total intl charge`

# %% [markdown]
# #### Answer 1

# %% [markdown]
# It is possible to add a column more easily without creating an intermediate Series instance.
#
# Let's do it to create `total charge` column using `total day charge`, `total eve charge`, `total night charge`, `total intl charge`

# %%
df['total charge'] = df['total day charge'] + df['total eve charge'] + \
                     df['total night charge'] + df['total intl charge']
df.head()
# Out:
#   state  account length area code phone number  international plan  \
# 0    KS             128       415      3824657               False
# 1    OH             107       415      3717191               False
# 2    NJ             137       415      3581921               False
# 3    OH              84       408      3759999                True
# 4    OK              75       415      3306626                True
#
#    voice mail plan  number vmail messages  total day minutes  total day calls  \
# 0                1                     25              265.1              110
# 1                1                     26              161.6              123
# 2                0                      0              243.4              114
# 3                0                      0              299.4               71
# 4                0                      0              166.7              113
#
#    total day charge  ...  total night charge  total intl minutes  \
# 0             45.07  ...               11.01                10.0
# 1             27.47  ...               11.45                13.7
# 2             41.38  ...                7.32                12.2
# 3             50.90  ...                8.86                 6.6
# 4             28.34  ...                8.41                10.1
#
#    total intl calls  total intl charge  customer service calls  churn  \
# 0                 3               2.70                       1      0
# 1                 3               3.70                       1      0
# 2                 5               3.29                       0      0
# 3                 7               1.78                       2      0
# 4                 3               2.73                       3      0
#
#    date joined  days since joined  total calls  total charge
# 0   2000-08-06               8872          303         75.56
# 1   2003-01-13               7982          332         59.24
# 2   2010-11-03               5131          333         62.29
# 3   2008-08-21               5935          255         66.80
# 4   1998-08-29               9580          359         52.09
#
# [5 rows x 25 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3333 entries, 0 to 3332
# Data columns (total 25 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   state                   3333 non-null   object
#  1   account length          3333 non-null   int64
#  2   area code               3333 non-null   object
#  3   phone number            3333 non-null   object
#  4   international plan      3333 non-null   bool
#  5   voice mail plan         3333 non-null   int64
#  6   number vmail messages   3333 non-null   int64
#  7   total day minutes       3333 non-null   float64
#  8   total day calls         3333 non-null   int64
#  9   total day charge        3333 non-null   float64
#  10  total eve minutes       3333 non-null   float64
#  11  total eve calls         3333 non-null   int64
#  12  total eve charge        3333 non-null   float64
#  13  total night minutes     3333 non-null   float64
#  14  total night calls       3333 non-null   int64
#  15  total night charge      3333 non-null   float64
#  16  total intl minutes      3333 non-null   float64
#  17  total intl calls        3333 non-null   int64
#  18  total intl charge       3333 non-null   float64
#  19  customer service calls  3333 non-null   int64
#  20  churn                   3333 non-null   int64
#  21  date joined             3333 non-null   datetime64[ns]
#  22  days since joined       3333 non-null   int64
#  23  total calls             3333 non-null   int64
#  24  total charge            3333 non-null   float64
# dtypes: bool(1), datetime64[ns](1), float64(9), int64(11), object(3)
# memory usage: 628.3+ KB

# %% [markdown]
# If needed - remove duplicated rows using Panda's `drop_duplicates` function

# %%
df.drop_duplicates(inplace=True)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3333 entries, 0 to 3332
# Data columns (total 25 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   state                   3333 non-null   object
#  1   account length          3333 non-null   int64
#  2   area code               3333 non-null   object
#  3   phone number            3333 non-null   object
#  4   international plan      3333 non-null   bool
#  5   voice mail plan         3333 non-null   int64
#  6   number vmail messages   3333 non-null   int64
#  7   total day minutes       3333 non-null   float64
#  8   total day calls         3333 non-null   int64
#  9   total day charge        3333 non-null   float64
#  10  total eve minutes       3333 non-null   float64
#  11  total eve calls         3333 non-null   int64
#  12  total eve charge        3333 non-null   float64
#  13  total night minutes     3333 non-null   float64
#  14  total night calls       3333 non-null   int64
#  15  total night charge      3333 non-null   float64
#  16  total intl minutes      3333 non-null   float64
#  17  total intl calls        3333 non-null   int64
#  18  total intl charge       3333 non-null   float64
#  19  customer service calls  3333 non-null   int64
#  20  churn                   3333 non-null   int64
#  21  date joined             3333 non-null   datetime64[ns]
#  22  days since joined       3333 non-null   int64
#  23  total calls             3333 non-null   int64
#  24  total charge            3333 non-null   float64
# dtypes: bool(1), datetime64[ns](1), float64(9), int64(11), object(3)
# memory usage: 628.3+ KB

# %% [markdown]
# To update a cell in the `DataFrame` use `loc` with the coordinates of the cell to by modified.

# %%
print ("Before update: {}".format(df.loc[0,'total intl charge']))
df.loc[0,'total intl charge'] = 4.4
print ("After update: {}".format(df.loc[0,'total intl charge']))
# Out:
# Before update: 2.7
# After update: 4.4

# %% [markdown]
# Referncing a particular cell is also possible using iloc and requires fetching the positional of the row and column to be changed.
#
# For instance let's set the second to last value of the *total charge* series:

# %%
print ("Before update: {}".format(df.iloc[-2, df.columns.get_loc('total charge')]))
df.iloc[-2, df.columns.get_loc('total charge')] = 0
print ("After update: {}".format(df.iloc[-2, df.columns.get_loc('total charge')]))
# Out:
# Before update: 57.53
# After update: 0.0

# %% [markdown]
# ####Question 2
#
# **let's update the elements of the *total charge* series where the element value is *not* greater than the series median value.**

# %% [markdown]
# #### Answer 2

# %%
# 1. get the indices of the rows that match the condition
ix = df[df['total charge']>=df['total charge'].median()].index
# 2. create a mask to be used for selection
mask = df.index.isin(ix)
# # use the inverted mask to zero the cells that do not match the condition
df.loc[~mask, 'total charge'] = 0

# %%
df['total charge']>=df['total charge'].median()
# Out:
# 0        True
# 1       False
# 2        True
# 3        True
# 4       False
#         ...
# 3328     True
# 3329     True
# 3330     True
# 3331    False
# 3332     True
# Name: total charge, Length: 3333, dtype: bool

# %%
df[df['total charge']>=df['total charge'].median()]
# Out:
#      state  account length area code phone number  international plan  \
# 0       KS             128       415      3824657               False
# 2       NJ             137       415      3581921               False
# 3       OH              84       408      3759999                True
# 5       AL             118       510      3918027                True
# 6       MA             121       510      3559993               False
# ...    ...             ...       ...          ...                 ...
# 3322    MD              62       408      4091856               False
# 3328    AZ             192       415      4144276               False
# 3329    WV              68       415      3703271               False
# 3330    RI              28       510      3288230               False
# 3332    TN              74       415      4004344               False
#
#       voice mail plan  number vmail messages  total day minutes  \
# 0                   1                     25              265.1
# 2                   0                      0              243.4
# 3                   0                      0              299.4
# 5                   0                      0              223.4
# 6                   1                     24              218.2
# ...               ...                    ...                ...
# 3322                0                      0              321.1
# 3328                1                     36              156.2
# 3329                0                      0              231.1
# 3330                0                      0              180.8
# 3332                1                     25              234.4
#
#       total day calls  total day charge  ...  total night charge  \
# 0                 110             45.07  ...               11.01
# 2                 114             41.38  ...                7.32
# 3                  71             50.90  ...                8.86
# 5                  98             37.98  ...                9.18
# 6                  88             37.09  ...                9.57
# ...               ...               ...  ...                 ...
# 3322              105             54.59  ...                8.12
# 3328               77             26.55  ...               12.56
# 3329               57             39.29  ...                8.61
# 3330              109             30.74  ...                8.64
# 3332              113             39.85  ...               10.86
#
#       total intl minutes  total intl calls  total intl charge  \
# 0                   10.0                 3               4.40
# 2                   12.2                 5               3.29
# 3                    6.6                 7               1.78
# 5                    6.3                 6               1.70
# 6                    7.5                 7               2.03
# ...                  ...               ...                ...
# 3322                11.5                 2               3.11
# 3328                 9.9                 6               2.67
# 3329                 9.6                 4               2.59
# 3330                14.1                 6               3.81
# 3332                13.7                 4               3.70
#
#       customer service calls  churn  date joined  days since joined  \
# 0                          1      0   2000-08-06               8872
# 2                          0      0   2010-11-03               5131
# 3                          2      0   2008-08-21               5935
# 5                          0      0   2014-12-17               3626
# 6                          3      0   1998-10-20               9528
# ...                      ...    ...          ...                ...
# 3322                       4      1   2005-12-17               6913
# 3328                       2      0   2001-02-07               8687
# 3329                       3      0   2017-06-21               2709
# 3330                       2      0   2000-04-21               8979
# 3332                       0      0   1998-06-03               9667
#
#       total calls  total charge
# 0             303         75.56
# 2             333         62.29
# 3             255         66.80
# 5             323         67.61
# 6             321         78.31
# ...           ...           ...
# 3322          301         88.39
# 3328          292         60.10
# 3329          239         63.53
# 3330          264         67.74
# 3332          276         77.01
#
# [1668 rows x 25 columns]

# %%
# To get rid of just created columns
df.drop(['total charge', 'total calls'], axis=1, inplace=True)

# %% [markdown]
# ####Textual data
#
# We might want to do transformations specific to textual data (`str` type).
#
# For example, we can choose to convert to a lowercase or uppercase style, remove digits or remove punctuations.
#
# A good source for tools to work with text is Regex: https://www.regexbuddy.com/
#
# Our current data does not include many text, but in the final project we will have text columns. A tutorial for EDA for textual data is: https://www.analyticsvidhya.com/blog/2020/04/beginners-guide-exploratory-data-analysis-text-data/#2

# %%
df['state']
# Out:
# 0       KS
# 1       OH
# 2       NJ
# 3       OH
# 4       OK
#         ..
# 3328    AZ
# 3329    WV
# 3330    RI
# 3331    CT
# 3332    TN
# Name: state, Length: 3333, dtype: object

# %%
df['state']=df['state'].apply(lambda x: x.lower())
df['state']
# Out:
# 0       ks
# 1       oh
# 2       nj
# 3       oh
# 4       ok
#         ..
# 3328    az
# 3329    wv
# 3330    ri
# 3331    ct
# 3332    tn
# Name: state, Length: 3333, dtype: object

# %% [markdown]
# ### Correlations
# Finding a correlation between numerical variables in the dataset.

# %%
df_numeric = df.select_dtypes(include=['number'])
correlation_mat = df_numeric.corr()
correlation_mat
# Out:
#                         account length  voice mail plan  \
# account length                1.000000         0.002918
# voice mail plan               0.002918         1.000000
# number vmail messages        -0.004628         0.956927
# total day minutes             0.006216        -0.001684
# total day calls               0.038470        -0.011086
# total day charge              0.006214        -0.001686
# total eve minutes            -0.006757         0.021545
# total eve calls               0.019260        -0.006444
# total eve charge             -0.006745         0.021559
# total night minutes          -0.008955         0.006079
# total night calls            -0.013176         0.015553
# total night charge           -0.008960         0.006064
# total intl minutes            0.009514        -0.001318
# total intl calls              0.020661         0.007618
# total intl charge             0.009996        -0.000182
# customer service calls       -0.003796        -0.017824
# churn                         0.016541        -0.102148
# days since joined            -0.026573        -0.000463
#
#                         number vmail messages  total day minutes  \
# account length                      -0.004628           0.006216
# voice mail plan                      0.956927          -0.001684
# number vmail messages                1.000000           0.000778
# total day minutes                    0.000778           1.000000
# total day calls                     -0.009548           0.006750
# total day charge                     0.000776           1.000000
# total eve minutes                    0.017562           0.007043
# total eve calls                     -0.005864           0.015769
# total eve charge                     0.017578           0.007029
# total night minutes                  0.007681           0.004323
# total night calls                    0.007123           0.022972
# total night charge                   0.007663           0.004300
# total intl minutes                   0.002856          -0.010155
# total intl calls                     0.013957           0.008033
# total intl charge                    0.003717          -0.009025
# customer service calls              -0.013263          -0.013423
# churn                               -0.089728           0.205151
# days since joined                   -0.000908          -0.011225
#
#                         total day calls  total day charge  total eve minutes  \
# account length                 0.038470          0.006214          -0.006757
# voice mail plan               -0.011086         -0.001686           0.021545
# number vmail messages         -0.009548          0.000776           0.017562
# total day minutes              0.006750          1.000000           0.007043
# total day calls                1.000000          0.006753          -0.021451
# total day charge               0.006753          1.000000           0.007050
# total eve minutes             -0.021451          0.007050           1.000000
# total eve calls                0.006462          0.015769          -0.011430
# total eve charge              -0.021449          0.007036           1.000000
# total night minutes            0.022938          0.004324          -0.012584
# total night calls             -0.019557          0.022972           0.007586
# total night charge             0.022927          0.004301          -0.012593
# total intl minutes             0.021565         -0.010157          -0.011035
# total intl calls               0.004574          0.008032           0.002541
# total intl charge              0.021973         -0.009027          -0.011107
# customer service calls        -0.018942         -0.013427          -0.012985
# churn                          0.018459          0.205151           0.092796
# days since joined              0.013562         -0.011219          -0.002558
#
#                         total eve calls  total eve charge  \
# account length                 0.019260         -0.006745
# voice mail plan               -0.006444          0.021559
# number vmail messages         -0.005864          0.017578
# total day minutes              0.015769          0.007029
# total day calls                0.006462         -0.021449
# total day charge               0.015769          0.007036
# total eve minutes             -0.011430          1.000000
# total eve calls                1.000000         -0.011423
# total eve charge              -0.011423          1.000000
# total night minutes           -0.002093         -0.012592
# total night calls              0.007710          0.007596
# total night charge            -0.002056         -0.012601
# total intl minutes             0.008703         -0.011043
# total intl calls               0.017434          0.002541
# total intl charge              0.008630         -0.011114
# customer service calls         0.002423         -0.012987
# churn                          0.009233          0.092786
# days since joined             -0.014924         -0.002550
#
#                         total night minutes  total night calls  \
# account length                    -0.008955          -0.013176
# voice mail plan                    0.006079           0.015553
# number vmail messages              0.007681           0.007123
# total day minutes                  0.004323           0.022972
# total day calls                    0.022938          -0.019557
# total day charge                   0.004324           0.022972
# total eve minutes                 -0.012584           0.007586
# total eve calls                   -0.002093           0.007710
# total eve charge                  -0.012592           0.007596
# total night minutes                1.000000           0.011204
# total night calls                  0.011204           1.000000
# total night charge                 0.999999           0.011188
# total intl minutes                -0.015207          -0.013605
# total intl calls                  -0.012353           0.000305
# total intl charge                 -0.014583          -0.013935
# customer service calls            -0.009288          -0.012802
# churn                              0.035493           0.006141
# days since joined                  0.010793           0.014120
#
#                         total night charge  total intl minutes  \
# account length                   -0.008960            0.009514
# voice mail plan                   0.006064           -0.001318
# number vmail messages             0.007663            0.002856
# total day minutes                 0.004300           -0.010155
# total day calls                   0.022927            0.021565
# total day charge                  0.004301           -0.010157
# total eve minutes                -0.012593           -0.011035
# total eve calls                  -0.002056            0.008703
# total eve charge                 -0.012601           -0.011043
# total night minutes               0.999999           -0.015207
# total night calls                 0.011188           -0.013605
# total night charge                1.000000           -0.015214
# total intl minutes               -0.015214            1.000000
# total intl calls                 -0.012329            0.032304
# total intl charge                -0.014590            0.999231
# customer service calls           -0.009277           -0.009640
# churn                             0.035496            0.068239
# days since joined                 0.010787            0.027376
#
#                         total intl calls  total intl charge  \
# account length                  0.020661           0.009996
# voice mail plan                 0.007618          -0.000182
# number vmail messages           0.013957           0.003717
# total day minutes               0.008033          -0.009025
# total day calls                 0.004574           0.021973
# total day charge                0.008032          -0.009027
# total eve minutes               0.002541          -0.011107
# total eve calls                 0.017434           0.008630
# total eve charge                0.002541          -0.011114
# total night minutes            -0.012353          -0.014583
# total night calls               0.000305          -0.013935
# total night charge             -0.012329          -0.014590
# total intl minutes              0.032304           0.999231
# total intl calls                1.000000           0.031943
# total intl charge               0.031943           1.000000
# customer service calls         -0.017561          -0.009957
# churn                          -0.052844           0.067932
# days since joined              -0.008734           0.027960
#
#                         customer service calls     churn  days since joined
# account length                       -0.003796  0.016541          -0.026573
# voice mail plan                      -0.017824 -0.102148          -0.000463
# number vmail messages                -0.013263 -0.089728          -0.000908
# total day minutes                    -0.013423  0.205151          -0.011225
# total day calls                      -0.018942  0.018459           0.013562
# total day charge                     -0.013427  0.205151          -0.011219
# total eve minutes                    -0.012985  0.092796          -0.002558
# total eve calls                       0.002423  0.009233          -0.014924
# total eve charge                     -0.012987  0.092786          -0.002550
# total night minutes                  -0.009288  0.035493           0.010793
# total night calls                    -0.012802  0.006141           0.014120
# total night charge                   -0.009277  0.035496           0.010787
# total intl minutes                   -0.009640  0.068239           0.027376
# total intl calls                     -0.017561 -0.052844          -0.008734
# total intl charge                    -0.009957  0.067932           0.027960
# customer service calls                1.000000  0.208750           0.007970
# churn                                 0.208750  1.000000           0.009468
# days since joined                     0.007970  0.009468           1.000000

# %% [markdown]
# We can also look at the correlation between all numeric variables and the target variable

# %%
cor_to_target = correlation_mat[['churn']]
cor_to_target.sort_values(by='churn', inplace=True)
plt.figure(figsize=(5,10))
sns.heatmap(cor_to_target, annot=True,linewidths=.5,cmap="YlGnBu")
# Out:
# <ipython-input-273-8d4335e4c834>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cor_to_target.sort_values(by='churn', inplace=True)
# <Axes: >
