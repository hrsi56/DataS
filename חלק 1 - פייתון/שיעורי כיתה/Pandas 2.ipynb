# %% [markdown]
# # Pandas 2
# © Advanced Analytics, Amir Ben Haim, 2024

# %% [markdown]
# ## Cleaning Data
#
# Data containing malformed strings, Python lists and missing data.
# Tidy it up so you can get on with the analysis.

# %% [markdown]
# <p style = "color:red" >Notice</p>
# <p style = "color:red" >This part is more technical than methodological </p>

# %%
### First we have to import the pandas libraries to the environment
import pandas as pd

# %% [markdown]
# <br>
# <hr class="dotted">
# <br>

# %% [markdown]
# ### Messy Data

# %% [markdown]
# Take a look at this terrible DataFrame,
# let's clean it up !

# %%
dic = {'Country': ['LoNDon_britian', 'Brussels_BelgIUm', 'MAdrid_spAIN', 'londON_briTiAn', 'Budapest_PraG','Brussels_BelgIUm'],
         'ProductId': [35, 77000, None, 53, None,77000],
         'SalesHistory': [[23, 47,88], [67, 32], [], [24, 43, 87], [13],[67, 32]],
         'Category': ['(Broken Glass. )', '98. Plastic', '<Hard Wood> (45)', 'STEEL(&)','"Lether"','98. Plastic'],
         'Date':['2018/12/01', '2017/10/05', '2018/11/11', None, '2017/06/10','2017/10/05'],
         'Division': [['div_a', 'sub_div_a'], ['div_b', 'sub_div_b'], [], ['div_c', 'sub_div_c'], ['div_d'],['div_b', 'sub_div_b']]
      }

df = pd.DataFrame(dic)
df
# Out:
#             Country  ProductId  SalesHistory          Category        Date  \
# 0    LoNDon_britian       35.0  [23, 47, 88]  (Broken Glass. )  2018/12/01
# 1  Brussels_BelgIUm    77000.0      [67, 32]       98. Plastic  2017/10/05
# 2      MAdrid_spAIN        NaN            []  <Hard Wood> (45)  2018/11/11
# 3    londON_briTiAn       53.0  [24, 43, 87]          STEEL(&)        None
# 4     Budapest_PraG        NaN          [13]          "Lether"  2017/06/10
# 5  Brussels_BelgIUm    77000.0      [67, 32]       98. Plastic  2017/10/05
#
#              Division
# 0  [div_a, sub_div_a]
# 1  [div_b, sub_div_b]
# 2                  []
# 3  [div_c, sub_div_c]
# 4             [div_d]
# 5  [div_b, sub_div_b]

# %% [markdown]
# <br>
# <hr class="dotted">
# <br>

# %% [markdown]
# ### Drop rows with Null

# %%
# dropna() --> Return a new Data Frame with no empty cells
df_new = df.dropna()
df_new
# Out:
#             Country  ProductId  SalesHistory          Category        Date  \
# 0    LoNDon_britian       35.0  [23, 47, 88]  (Broken Glass. )  2018/12/01
# 1  Brussels_BelgIUm    77000.0      [67, 32]       98. Plastic  2017/10/05
# 5  Brussels_BelgIUm    77000.0      [67, 32]       98. Plastic  2017/10/05
#
#              Division
# 0  [div_a, sub_div_a]
# 1  [div_b, sub_div_b]
# 5  [div_b, sub_div_b]

# %%
# dropna()  -->  By default, the method returns a new DataFrame, and will not change the original
df.dropna()
df
# Nothing happened
# Out:
#             Country  ProductId  SalesHistory          Category        Date  \
# 0    LoNDon_britian       35.0  [23, 47, 88]  (Broken Glass. )  2018/12/01
# 1  Brussels_BelgIUm    77000.0      [67, 32]       98. Plastic  2017/10/05
# 2      MAdrid_spAIN        NaN            []  <Hard Wood> (45)  2018/11/11
# 3    londON_briTiAn       53.0  [24, 43, 87]          STEEL(&)        None
# 4     Budapest_PraG        NaN          [13]          "Lether"  2017/06/10
# 5  Brussels_BelgIUm    77000.0      [67, 32]       98. Plastic  2017/10/05
#
#              Division
# 0  [div_a, sub_div_a]
# 1  [div_b, sub_div_b]
# 2                  []
# 3  [div_c, sub_div_c]
# 4             [div_d]
# 5  [div_b, sub_div_b]

# %%
# If you want to change the original DataFrame, use the "inplace = True" argument
df.dropna(inplace = True)
df
# Out:
#             Country  ProductId  SalesHistory          Category        Date  \
# 0    LoNDon_britian       35.0  [23, 47, 88]  (Broken Glass. )  2018/12/01
# 1  Brussels_BelgIUm    77000.0      [67, 32]       98. Plastic  2017/10/05
# 5  Brussels_BelgIUm    77000.0      [67, 32]       98. Plastic  2017/10/05
#
#              Division
# 0  [div_a, sub_div_a]
# 1  [div_b, sub_div_b]
# 5  [div_b, sub_div_b]

# %%
# Back to empty rows
df = pd.DataFrame(dic)
df
# Out:
#             Country  ProductId  SalesHistory          Category        Date  \
# 0    LoNDon_britian       35.0  [23, 47, 88]  (Broken Glass. )  2018/12/01
# 1  Brussels_BelgIUm    77000.0      [67, 32]       98. Plastic  2017/10/05
# 2      MAdrid_spAIN        NaN            []  <Hard Wood> (45)  2018/11/11
# 3    londON_briTiAn       53.0  [24, 43, 87]          STEEL(&)        None
# 4     Budapest_PraG        NaN          [13]          "Lether"  2017/06/10
# 5  Brussels_BelgIUm    77000.0      [67, 32]       98. Plastic  2017/10/05
#
#              Division
# 0  [div_a, sub_div_a]
# 1  [div_b, sub_div_b]
# 2                  []
# 3  [div_c, sub_div_c]
# 4             [div_d]
# 5  [div_b, sub_div_b]

# %% [markdown]
# <br>
# <hr class="dotted">
# <br>

# %% [markdown]
# ### Fill rows that contain Null

# %%
# If we don't want to delete entire rows just because of some empty cells
# We can use "fillna()" method --> replace empty cells with a value
df.fillna(100,inplace = True)
df
# Out:
#             Country  ProductId  SalesHistory          Category        Date  \
# 0    LoNDon_britian       35.0  [23, 47, 88]  (Broken Glass. )  2018/12/01
# 1  Brussels_BelgIUm    77000.0      [67, 32]       98. Plastic  2017/10/05
# 2      MAdrid_spAIN      100.0            []  <Hard Wood> (45)  2018/11/11
# 3    londON_briTiAn       53.0  [24, 43, 87]          STEEL(&)         100
# 4     Budapest_PraG      100.0          [13]          "Lether"  2017/06/10
# 5  Brussels_BelgIUm    77000.0      [67, 32]       98. Plastic  2017/10/05
#
#              Division
# 0  [div_a, sub_div_a]
# 1  [div_b, sub_div_b]
# 2                  []
# 3  [div_c, sub_div_c]
# 4             [div_d]
# 5  [div_b, sub_div_b]

# %%
# accidently it field also column "Date" with the value 100, which we didn't want
# Back to empty rows
df = pd.DataFrame(dic)
df
# Out:
#             Country  ProductId  SalesHistory          Category        Date  \
# 0    LoNDon_britian       35.0  [23, 47, 88]  (Broken Glass. )  2018/12/01
# 1  Brussels_BelgIUm    77000.0      [67, 32]       98. Plastic  2017/10/05
# 2      MAdrid_spAIN        NaN            []  <Hard Wood> (45)  2018/11/11
# 3    londON_briTiAn       53.0  [24, 43, 87]          STEEL(&)        None
# 4     Budapest_PraG        NaN          [13]          "Lether"  2017/06/10
# 5  Brussels_BelgIUm    77000.0      [67, 32]       98. Plastic  2017/10/05
#
#              Division
# 0  [div_a, sub_div_a]
# 1  [div_b, sub_div_b]
# 2                  []
# 3  [div_c, sub_div_c]
# 4             [div_d]
# 5  [div_b, sub_div_b]

# %%
# Replace Only For a Specified Columns
df.fillna({'ProductId':100},inplace = True)
df
# Out:
#             Country  ProductId  SalesHistory          Category        Date  \
# 0    LoNDon_britian       35.0  [23, 47, 88]  (Broken Glass. )  2018/12/01
# 1  Brussels_BelgIUm    77000.0      [67, 32]       98. Plastic  2017/10/05
# 2      MAdrid_spAIN      100.0            []  <Hard Wood> (45)  2018/11/11
# 3    londON_briTiAn       53.0  [24, 43, 87]          STEEL(&)        None
# 4     Budapest_PraG      100.0          [13]          "Lether"  2017/06/10
# 5  Brussels_BelgIUm    77000.0      [67, 32]       98. Plastic  2017/10/05
#
#              Division
# 0  [div_a, sub_div_a]
# 1  [div_b, sub_div_b]
# 2                  []
# 3  [div_c, sub_div_c]
# 4             [div_d]
# 5  [div_b, sub_div_b]

# %%
df.dtypes
# Out:
# Country          object
# ProductId       float64
# SalesHistory     object
# Category         object
# Date             object
# Division         object
# dtype: object

# %% [markdown]
# <br>
# <hr class="dotted">
# <br>

# %% [markdown]
# ### Change Data Type to <code>Date</code>

# %%
# the "Date" column has 2 problemetic rows, the third and four rows.
# "to_datetime()"" method can fix that
df.Date = pd.to_datetime(df.Date)
df
# Out:
#             Country  ProductId  SalesHistory          Category       Date  \
# 0    LoNDon_britian       35.0  [23, 47, 88]  (Broken Glass. ) 2018-12-01
# 1  Brussels_BelgIUm    77000.0      [67, 32]       98. Plastic 2017-10-05
# 2      MAdrid_spAIN      100.0            []  <Hard Wood> (45) 2018-11-11
# 3    londON_briTiAn       53.0  [24, 43, 87]          STEEL(&)        NaT
# 4     Budapest_PraG      100.0          [13]          "Lether" 2017-06-10
# 5  Brussels_BelgIUm    77000.0      [67, 32]       98. Plastic 2017-10-05
#
#              Division
# 0  [div_a, sub_div_a]
# 1  [div_b, sub_div_b]
# 2                  []
# 3  [div_c, sub_div_c]
# 4             [div_d]
# 5  [div_b, sub_div_b]

# %%
df.dtypes
# Out:
# Country                 object
# ProductId              float64
# SalesHistory            object
# Category                object
# Date            datetime64[ns]
# Division                object
# dtype: object

# %%
# Worked greate, accept for the empty date in row 3 got a "NaT" (Not a Time) value, in other words an empty value.
# One way to deal with empty values is simply removing the entire row.
df.dropna(subset=['Date'], inplace = True)
df
# Out:
#             Country  ProductId  SalesHistory          Category       Date  \
# 0    LoNDon_britian       35.0  [23, 47, 88]  (Broken Glass. ) 2018-12-01
# 1  Brussels_BelgIUm    77000.0      [67, 32]       98. Plastic 2017-10-05
# 2      MAdrid_spAIN      100.0            []  <Hard Wood> (45) 2018-11-11
# 4     Budapest_PraG      100.0          [13]          "Lether" 2017-06-10
# 5  Brussels_BelgIUm    77000.0      [67, 32]       98. Plastic 2017-10-05
#
#              Division
# 0  [div_a, sub_div_a]
# 1  [div_b, sub_div_b]
# 2                  []
# 4             [div_d]
# 5  [div_b, sub_div_b]

# %% [markdown]
# <br>
# <hr class="dotted">
# <br>

# %% [markdown]
# ### Update (hard coded) a Specific Value

# %%
# Look at ProductId 35, the ProductId should be 40
# Let's replace the value
df.loc[0,"ProductId"] = 40
df
# Out:
#             Country  ProductId  SalesHistory          Category       Date  \
# 0    LoNDon_britian       40.0  [23, 47, 88]  (Broken Glass. ) 2018-12-01
# 1  Brussels_BelgIUm    77000.0      [67, 32]       98. Plastic 2017-10-05
# 2      MAdrid_spAIN      100.0            []  <Hard Wood> (45) 2018-11-11
# 4     Budapest_PraG      100.0          [13]          "Lether" 2017-06-10
# 5  Brussels_BelgIUm    77000.0      [67, 32]       98. Plastic 2017-10-05
#
#              Division
# 0  [div_a, sub_div_a]
# 1  [div_b, sub_div_b]
# 2                  []
# 4             [div_d]
# 5  [div_b, sub_div_b]

# %% [markdown]
# <br>
# <hr class="dotted">
# <br>

# %% [markdown]
# ### Loop through <code>df</code>

# %%
df.index
# Out:
# Index([0, 1, 2, 4, 5], dtype='int64')

# %%
# Also we'll replace values bigger or equal to 100 with a loop
for i in df.index:
        while df.loc[i,"ProductId"] >= 100:
            df.loc[i,"ProductId"] = df.loc[i,"ProductId"] / 10
df
# Out:
#             Country  ProductId  SalesHistory          Category       Date  \
# 0    LoNDon_britian       40.0  [23, 47, 88]  (Broken Glass. ) 2018-12-01
# 1  Brussels_BelgIUm       77.0      [67, 32]       98. Plastic 2017-10-05
# 2      MAdrid_spAIN       10.0            []  <Hard Wood> (45) 2018-11-11
# 4     Budapest_PraG       10.0          [13]          "Lether" 2017-06-10
# 5  Brussels_BelgIUm       77.0      [67, 32]       98. Plastic 2017-10-05
#
#              Division
# 0  [div_a, sub_div_a]
# 1  [div_b, sub_div_b]
# 2                  []
# 4             [div_d]
# 5  [div_b, sub_div_b]

# %% [markdown]
# Another way to iterrate on df

# %%
for index, row in df.iterrows():
    print(index)
    print('')
    print(row)
    print('')
    print('')
    print('')
# Out:
# 0
#
# Country              LoNDon_britian
# ProductId                      40.0
# SalesHistory           [23, 47, 88]
# Category           (Broken Glass. )
# Date            2018-12-01 00:00:00
# Division         [div_a, sub_div_a]
# Name: 0, dtype: object
#
#
#
# 1
#
# Country            Brussels_BelgIUm
# ProductId                      77.0
# SalesHistory               [67, 32]
# Category                98. Plastic
# Date            2017-10-05 00:00:00
# Division         [div_b, sub_div_b]
# Name: 1, dtype: object
#
#
#
# 2
#
# Country                MAdrid_spAIN
# ProductId                      10.0
# SalesHistory                     []
# Category           <Hard Wood> (45)
# Date            2018-11-11 00:00:00
# Division                         []
# Name: 2, dtype: object
#
#
#
# 4
#
# Country               Budapest_PraG
# ProductId                      10.0
# SalesHistory                   [13]
# Category                   "Lether"
# Date            2017-06-10 00:00:00
# Division                    [div_d]
# Name: 4, dtype: object
#
#
#
# 5
#
# Country            Brussels_BelgIUm
# ProductId                      77.0
# SalesHistory               [67, 32]
# Category                98. Plastic
# Date            2017-10-05 00:00:00
# Division         [div_b, sub_div_b]
# Name: 5, dtype: object

# %% [markdown]
# <br>
# <hr class="dotted">
# <br>

# %% [markdown]
# ### Adding new rows (hard coded)

# %%
df
# Out:
#             Country  ProductId  SalesHistory          Category       Date  \
# 0    LoNDon_britian       40.0  [23, 47, 88]  (Broken Glass. ) 2018-12-01
# 1  Brussels_BelgIUm       77.0      [67, 32]       98. Plastic 2017-10-05
# 2      MAdrid_spAIN       10.0            []  <Hard Wood> (45) 2018-11-11
# 4     Budapest_PraG       10.0          [13]          "Lether" 2017-06-10
# 5  Brussels_BelgIUm       77.0      [67, 32]       98. Plastic 2017-10-05
#
#              Division
# 0  [div_a, sub_div_a]
# 1  [div_b, sub_div_b]
# 2                  []
# 4             [div_d]
# 5  [div_b, sub_div_b]

# %%
# Adding a row
df.loc[6] = ['Tel-Aviv_Israel', None, [15], 'Iron', '2020-01-01',['div_e']]
df.loc[7] = ['Haifa_Israel', 88, [15,80], 'Iron', '2020-01-01',['div_e']]
df.Date = pd.to_datetime(df.Date)
df
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_1312\1690261283.py:2: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df.loc[6] = ['Tel-Aviv_Israel', None, [15], 'Iron', '2020-01-01',['div_e']]
#             Country  ProductId  SalesHistory          Category       Date  \
# 0    LoNDon_britian       40.0  [23, 47, 88]  (Broken Glass. ) 2018-12-01
# 1  Brussels_BelgIUm       77.0      [67, 32]       98. Plastic 2017-10-05
# 2      MAdrid_spAIN       10.0            []  <Hard Wood> (45) 2018-11-11
# 4     Budapest_PraG       10.0          [13]          "Lether" 2017-06-10
# 5  Brussels_BelgIUm       77.0      [67, 32]       98. Plastic 2017-10-05
# 6   Tel-Aviv_Israel        NaN          [15]              Iron 2020-01-01
# 7      Haifa_Israel       88.0      [15, 80]              Iron 2020-01-01
#
#              Division
# 0  [div_a, sub_div_a]
# 1  [div_b, sub_div_b]
# 2                  []
# 4             [div_d]
# 5  [div_b, sub_div_b]
# 6             [div_e]
# 7             [div_e]

# %%
df

# %% [markdown]
# <br>
# <hr class="dotted">
# <br>

# %% [markdown]
# ### Adding new Column (hard coded)

# %%
# Add a new column
ProductName = ['bottle', 'chair', 'shelf', 'jacket', 'table', 'hammer', 'hammer']

df['ProductName'] = ProductName
df
# Out:
#             Country  ProductId  SalesHistory          Category       Date  \
# 0    LoNDon_britian       40.0  [23, 47, 88]  (Broken Glass. ) 2018-12-01
# 1  Brussels_BelgIUm       77.0      [67, 32]       98. Plastic 2017-10-05
# 2      MAdrid_spAIN       10.0            []  <Hard Wood> (45) 2018-11-11
# 4     Budapest_PraG       10.0          [13]          "Lether" 2017-06-10
# 5  Brussels_BelgIUm       77.0      [67, 32]       98. Plastic 2017-10-05
# 6   Tel-Aviv_Israel        NaN          [15]              Iron 2020-01-01
# 7      Haifa_Israel       88.0      [15, 80]              Iron 2020-01-01
#
#              Division ProductName
# 0  [div_a, sub_div_a]      bottle
# 1  [div_b, sub_div_b]       chair
# 2                  []       shelf
# 4             [div_d]      jacket
# 5  [div_b, sub_div_b]       table
# 6             [div_e]      hammer
# 7             [div_e]      hammer

# %% [markdown]
# <br>
# <hr class="dotted">
# <br>

# %% [markdown]
# ### Drop Column

# %%
# Drop new column "ProductName"
df.drop('ProductName',axis=1, inplace = True)
df
# Out:
#             Country  ProductId  SalesHistory          Category       Date  \
# 0    LoNDon_britian       40.0  [23, 47, 88]  (Broken Glass. ) 2018-12-01
# 1  Brussels_BelgIUm       77.0      [67, 32]       98. Plastic 2017-10-05
# 2      MAdrid_spAIN       10.0            []  <Hard Wood> (45) 2018-11-11
# 4     Budapest_PraG       10.0          [13]          "Lether" 2017-06-10
# 5  Brussels_BelgIUm       77.0      [67, 32]       98. Plastic 2017-10-05
# 6   Tel-Aviv_Israel        NaN          [15]              Iron 2020-01-01
# 7      Haifa_Israel       88.0      [15, 80]              Iron 2020-01-01
#
#              Division
# 0  [div_a, sub_div_a]
# 1  [div_b, sub_div_b]
# 2                  []
# 4             [div_d]
# 5  [div_b, sub_div_b]
# 6             [div_e]
# 7             [div_e]

# %% [markdown]
# <br>
# <hr class="dotted">
# <br>

# %% [markdown]
# ### Drop Row

# %%
# Drop row index 6
df.drop(6, inplace=True)
df
# Out:
#             Country  ProductId  SalesHistory          Category       Date  \
# 0    LoNDon_britian       40.0  [23, 47, 88]  (Broken Glass. ) 2018-12-01
# 1  Brussels_BelgIUm       77.0      [67, 32]       98. Plastic 2017-10-05
# 2      MAdrid_spAIN       10.0            []  <Hard Wood> (45) 2018-11-11
# 4     Budapest_PraG       10.0          [13]          "Lether" 2017-06-10
# 5  Brussels_BelgIUm       77.0      [67, 32]       98. Plastic 2017-10-05
# 7      Haifa_Israel       88.0      [15, 80]              Iron 2020-01-01
#
#              Division
# 0  [div_a, sub_div_a]
# 1  [div_b, sub_div_b]
# 2                  []
# 4             [div_d]
# 5  [div_b, sub_div_b]
# 7             [div_e]

# %% [markdown]
# <br>
# <hr class="dotted">
# <br>

# %% [markdown]
# ### Convert Data Type

# %%
# Change "ProductId" column to int
df['ProductId'] = df['ProductId'].astype(int)
df
# Out:
#             Country  ProductId  SalesHistory          Category       Date  \
# 0    LoNDon_britian         40  [23, 47, 88]  (Broken Glass. ) 2018-12-01
# 1  Brussels_BelgIUm         77      [67, 32]       98. Plastic 2017-10-05
# 2      MAdrid_spAIN         10            []  <Hard Wood> (45) 2018-11-11
# 4     Budapest_PraG         10          [13]          "Lether" 2017-06-10
# 5  Brussels_BelgIUm         77      [67, 32]       98. Plastic 2017-10-05
# 7      Haifa_Israel         88      [15, 80]              Iron 2020-01-01
#
#              Division
# 0  [div_a, sub_div_a]
# 1  [div_b, sub_div_b]
# 2                  []
# 4             [div_d]
# 5  [div_b, sub_div_b]
# 7             [div_e]

# %% [markdown]
# <br>
# <hr class="dotted">
# <br>

# %% [markdown]
# ### Split Column based on Delimiter

# %%
# Let's organize the horible column "Country"
# First we'll split it into columns and save them in a temporary variable
x = df.Country.str.split('_', expand=True)
x
# Out:
#           0        1
# 0    LoNDon  britian
# 1  Brussels  BelgIUm
# 2    MAdrid    spAIN
# 4  Budapest     PraG
# 5  Brussels  BelgIUm
# 7     Haifa   Israel

# %%
# And rename the columns of x as:
x.columns = ["City", "Country"]
x
# Out:
#        City  Country
# 0    LoNDon  britian
# 1  Brussels  BelgIUm
# 2    MAdrid    spAIN
# 4  Budapest     PraG
# 5  Brussels  BelgIUm
# 7     Haifa   Israel

# %%
# Then, standardise the string capitalisation so that only the first letter is uppercase  (e.g. "londON" should become "London".)
x["City"] = x.City.str.capitalize()
x["Country"] = x.Country.str.capitalize()
x
# Out:
#        City  Country
# 0    London  Britian
# 1  Brussels  Belgium
# 2    Madrid    Spain
# 4  Budapest     Prag
# 5  Brussels  Belgium
# 7     Haifa   Israel

# %%
df
# Out:
#             Country  ProductId  SalesHistory          Category       Date  \
# 0    LoNDon_britian         40  [23, 47, 88]  (Broken Glass. ) 2018-12-01
# 1  Brussels_BelgIUm         77      [67, 32]       98. Plastic 2017-10-05
# 2      MAdrid_spAIN         10            []  <Hard Wood> (45) 2018-11-11
# 4     Budapest_PraG         10          [13]          "Lether" 2017-06-10
# 5  Brussels_BelgIUm         77      [67, 32]       98. Plastic 2017-10-05
# 7      Haifa_Israel         88      [15, 80]              Iron 2020-01-01
#
#              Division
# 0  [div_a, sub_div_a]
# 1  [div_b, sub_div_b]
# 2                  []
# 4             [div_d]
# 5  [div_b, sub_div_b]
# 7             [div_e]

# %%
# Last we'll drop the column "Country" from "df" and add the 2 new columns from "x"
df = df.drop('Country',axis=1)
df = df.join(x)
df
# Out:
#    ProductId  SalesHistory          Category       Date            Division  \
# 0         40  [23, 47, 88]  (Broken Glass. ) 2018-12-01  [div_a, sub_div_a]
# 1         77      [67, 32]       98. Plastic 2017-10-05  [div_b, sub_div_b]
# 2         10            []  <Hard Wood> (45) 2018-11-11                  []
# 4         10          [13]          "Lether" 2017-06-10             [div_d]
# 5         77      [67, 32]       98. Plastic 2017-10-05  [div_b, sub_div_b]
# 7         88      [15, 80]              Iron 2020-01-01             [div_e]
#
#        City  Country
# 0    London  Britian
# 1  Brussels  Belgium
# 2    Madrid    Spain
# 4  Budapest     Prag
# 5  Brussels  Belgium
# 7     Haifa   Israel

# %% [markdown]
# <br>
# <hr class="dotted">
# <br>

# %% [markdown]
# ### Change the order the columns

# %%
# Change the order the columns
c = ["Country", "City", "ProductId", "Category","Division","Date", "SalesHistory"]


df = df[c]
df
# Out:
#    Country      City  ProductId          Category            Division  \
# 0  Britian    London         40  (Broken Glass. )  [div_a, sub_div_a]
# 1  Belgium  Brussels         77       98. Plastic  [div_b, sub_div_b]
# 2    Spain    Madrid         10  <Hard Wood> (45)                  []
# 4     Prag  Budapest         10          "Lether"             [div_d]
# 5  Belgium  Brussels         77       98. Plastic  [div_b, sub_div_b]
# 7   Israel     Haifa         88              Iron             [div_e]
#
#         Date  SalesHistory
# 0 2018-12-01  [23, 47, 88]
# 1 2017-10-05      [67, 32]
# 2 2018-11-11            []
# 4 2017-06-10          [13]
# 5 2017-10-05      [67, 32]
# 7 2020-01-01      [15, 80]

# %% [markdown]
# <br>
# <hr class="dotted">
# <br>

# %% [markdown]
# ### Extract / Clean str column - based on regx expr

# %% [markdown]
# #### Regex Expressions
#
# Python regex (regular expressions) are patterns used to match strings or substrings based on specific rules.
#
# <br>
# <u>Key Components:</u>
# <ul>
# <li>Literal Characters: Match exact text (e.g., <code>abc</code> matches "abc")</li>
# <br>
# <li>Metacharacters: Special symbols with unique meanings:</li>
#     <ul>
#         <li><code>.</code> Matches any character except newline.
#         <li><code>^</code> Matches the start of a string.
#         <li><code>$</code> Matches the end of a string.
#         <li><code>*, +, ?</code> Specify repetitions.
#         <li><code>[]</code> Matches any character in the set (e.g., <code>[abc]</code>).
#         <li><code>|</code> Acts as OR (e.g., <code>a|b</code> matches "a" or "b").
#         <li><code>\</code> Escapes metacharacters or introduces special sequences (e.g., <code>\d</code> for digits).
# </ul>

# %%
df
# Out:
#    Country      City  ProductId          Category            Division  \
# 0  Britian    London         40  (Broken Glass. )  [div_a, sub_div_a]
# 1  Belgium  Brussels         77       98. Plastic  [div_b, sub_div_b]
# 2    Spain    Madrid         10  <Hard Wood> (45)                  []
# 4     Prag  Budapest         10          "Lether"             [div_d]
# 5  Belgium  Brussels         77       98. Plastic  [div_b, sub_div_b]
# 7   Israel     Haifa         88              Iron             [div_e]
#
#         Date  SalesHistory
# 0 2018-12-01  [23, 47, 88]
# 1 2017-10-05      [67, 32]
# 2 2018-11-11            []
# 4 2017-06-10          [13]
# 5 2017-10-05      [67, 32]
# 7 2020-01-01      [15, 80]

# %%
# Remove unwanted characters from "Category" column with "str.extract"
# "expand" argument equals "False", keeps the the values in one column
df['Category'] = df['Category'].str.extract('([a-zA-Z\\s]+)', expand=False)
df
# Out:
#    Country      City  ProductId      Category            Division       Date  \
# 0  Britian    London         40  Broken Glass  [div_a, sub_div_a] 2018-12-01
# 1  Belgium  Brussels         77       Plastic  [div_b, sub_div_b] 2017-10-05
# 2    Spain    Madrid         10     Hard Wood                  [] 2018-11-11
# 4     Prag  Budapest         10        Lether             [div_d] 2017-06-10
# 5  Belgium  Brussels         77       Plastic  [div_b, sub_div_b] 2017-10-05
# 7   Israel     Haifa         88          Iron             [div_e] 2020-01-01
#
#    SalesHistory
# 0  [23, 47, 88]
# 1      [67, 32]
# 2            []
# 4          [13]
# 5      [67, 32]
# 7      [15, 80]

# %% [markdown]
# <u>In the Example above:</u>
# <br>The regex <code>([a-zA-Z\s]+)</code> matches one or more (<code>+</code>) characters that are either:
#
# - Lowercase letters (<code>a-z</code>),
# - Uppercase letters (<code>A-Z</code>), or
# - Whitespace characters (<code>\s</code>)
# <br></br>The parentheses <code>()</code> create a capturing group for these matched characters.

# %%
# str.strip()
# Remove spaces at the beginning and at the end of the string
df['Category'] = df['Category'].str.strip()
df
# Out:
#    Country      City  ProductId      Category            Division       Date  \
# 0  Britian    London         40  Broken Glass  [div_a, sub_div_a] 2018-12-01
# 1  Belgium  Brussels         77       Plastic  [div_b, sub_div_b] 2017-10-05
# 2    Spain    Madrid         10     Hard Wood                  [] 2018-11-11
# 4     Prag  Budapest         10        Lether             [div_d] 2017-06-10
# 5  Belgium  Brussels         77       Plastic  [div_b, sub_div_b] 2017-10-05
# 7   Israel     Haifa         88          Iron             [div_e] 2020-01-01
#
#    SalesHistory
# 0  [23, 47, 88]
# 1      [67, 32]
# 2            []
# 4          [13]
# 5      [67, 32]
# 7      [15, 80]

# %% [markdown]
# <br>
# <hr class="dotted">
# <br>

# %% [markdown]
# ### Handling non scalar values - <code>lists</code> to columns

# %%
# We want to fix "Division" column, the values there have been added as lists
# We want every value to be in it's own column
# We'll create a temporary variable with 2 column using the "apply" method
T = df['Division'].apply(pd.Series, dtype='object')
T
# Out:
#        0          1
# 0  div_a  sub_div_a
# 1  div_b  sub_div_b
# 2    NaN        NaN
# 4  div_d        NaN
# 5  div_b  sub_div_b
# 7  div_e        NaN

# %%
range(1,3)
# Out:
# range(1, 3)

# %%
[f'Division_{v}' for v in range(1,len(T.columns)+1)]
# Out:
# ['Division_1', 'Division_2']

# %%
# And rename "T" variable columns using a loop
T.columns = [f'Division_{v}' for v in range(1,len(T.columns)+1)]
T
# Out:
#   Division_1 Division_2
# 0      div_a  sub_div_a
# 1      div_b  sub_div_b
# 2        NaN        NaN
# 4      div_d        NaN
# 5      div_b  sub_div_b
# 7      div_e        NaN

# %%
# Last (like before) we'll drop the unwanted colum and "join" the 2 new columns
df = df.drop('Division', axis=1).join(T)
df
# Out:
#    Country      City  ProductId      Category       Date  SalesHistory  \
# 0  Britian    London         40  Broken Glass 2018-12-01  [23, 47, 88]
# 1  Belgium  Brussels         77       Plastic 2017-10-05      [67, 32]
# 2    Spain    Madrid         10     Hard Wood 2018-11-11            []
# 4     Prag  Budapest         10        Lether 2017-06-10          [13]
# 5  Belgium  Brussels         77       Plastic 2017-10-05      [67, 32]
# 7   Israel     Haifa         88          Iron 2020-01-01      [15, 80]
#
#   Division_1 Division_2
# 0      div_a  sub_div_a
# 1      div_b  sub_div_b
# 2        NaN        NaN
# 4      div_d        NaN
# 5      div_b  sub_div_b
# 7      div_e        NaN

# %%
df.fillna('no_div',inplace = True)
df
# Out:
#    Country      City  ProductId      Category       Date  SalesHistory  \
# 0  Britian    London         40  Broken Glass 2018-12-01  [23, 47, 88]
# 1  Belgium  Brussels         77       Plastic 2017-10-05      [67, 32]
# 2    Spain    Madrid         10     Hard Wood 2018-11-11            []
# 4     Prag  Budapest         10        Lether 2017-06-10          [13]
# 5  Belgium  Brussels         77       Plastic 2017-10-05      [67, 32]
# 7   Israel     Haifa         88          Iron 2020-01-01      [15, 80]
#
#   Division_1 Division_2
# 0      div_a  sub_div_a
# 1      div_b  sub_div_b
# 2     no_div     no_div
# 4      div_d     no_div
# 5      div_b  sub_div_b
# 7      div_e     no_div

# %% [markdown]
# <br>
# <hr class="dotted">
# <br>

# %% [markdown]
# ### Concat <code>df's</code>

# %%
# Create a new df2

dic2 = {'Country': ['India', 'France'],
       'City': ['Delhi', 'Paris'],
        'ProductId': [40, 88],
        'Category': ['Broken Glass','Iron'],
        'Date':['2018-12-01', '2017-10-05'],
        'SalesHistory': [[23, 47,88], [67, 32]],
        'Division_1':['div_a','div_b'],
        'Division_2':['sub_div_a','sub_div_b']
        }


df2 = pd.DataFrame(dic2)
df2
# Out:
#   Country   City  ProductId      Category        Date  SalesHistory  \
# 0   India  Delhi         40  Broken Glass  2018-12-01  [23, 47, 88]
# 1  France  Paris         88          Iron  2017-10-05      [67, 32]
#
#   Division_1 Division_2
# 0      div_a  sub_div_a
# 1      div_b  sub_div_b

# %%
df
# Out:
#    Country      City  ProductId      Category       Date  SalesHistory  \
# 0  Britian    London         40  Broken Glass 2018-12-01  [23, 47, 88]
# 1  Belgium  Brussels         77       Plastic 2017-10-05      [67, 32]
# 2    Spain    Madrid         10     Hard Wood 2018-11-11            []
# 4     Prag  Budapest         10        Lether 2017-06-10          [13]
# 5  Belgium  Brussels         77       Plastic 2017-10-05      [67, 32]
# 7   Israel     Haifa         88          Iron 2020-01-01      [15, 80]
#
#   Division_1 Division_2
# 0      div_a  sub_div_a
# 1      div_b  sub_div_b
# 2     no_div     no_div
# 4      div_d     no_div
# 5      div_b  sub_div_b
# 7      div_e     no_div

# %%
# Concat df2 to df
df = pd.concat([df, df2], ignore_index=True)

df.Date = pd.to_datetime(df.Date)
df
# Out:
#     Country      City  ProductId      Category       Date  SalesHistory  \
# 0   Britian    London         40  Broken Glass 2018-12-01  [23, 47, 88]
# 1   Belgium  Brussels         77       Plastic 2017-10-05      [67, 32]
# 2     Spain    Madrid         10     Hard Wood 2018-11-11            []
# 3      Prag  Budapest         10        Lether 2017-06-10          [13]
# 4   Belgium  Brussels         77       Plastic 2017-10-05      [67, 32]
# 5    Israel     Haifa         88          Iron 2020-01-01      [15, 80]
# 6     India     Delhi         40  Broken Glass 2018-12-01  [23, 47, 88]
# 7    France     Paris         88          Iron 2017-10-05      [67, 32]
# 8     India     Delhi         40  Broken Glass 2018-12-01  [23, 47, 88]
# 9    France     Paris         88          Iron 2017-10-05      [67, 32]
# 10    India     Delhi         40  Broken Glass 2018-12-01  [23, 47, 88]
# 11   France     Paris         88          Iron 2017-10-05      [67, 32]
#
#    Division_1 Division_2
# 0       div_a  sub_div_a
# 1       div_b  sub_div_b
# 2      no_div     no_div
# 3       div_d     no_div
# 4       div_b  sub_div_b
# 5       div_e     no_div
# 6       div_a  sub_div_a
# 7       div_b  sub_div_b
# 8       div_a  sub_div_a
# 9       div_b  sub_div_b
# 10      div_a  sub_div_a
# 11      div_b  sub_div_b

# %%
df
# Out:
#    Country      City  ProductId      Category       Date  SalesHistory  \
# 0  Britian    London         40  Broken Glass 2018-12-01  [23, 47, 88]
# 1  Belgium  Brussels         77       Plastic 2017-10-05      [67, 32]
# 2    Spain    Madrid         10     Hard Wood 2018-11-11            []
# 3     Prag  Budapest         10        Lether 2017-06-10          [13]
# 4  Belgium  Brussels         77       Plastic 2017-10-05      [67, 32]
# 5   Israel     Haifa         88          Iron 2020-01-01      [15, 80]
# 6    India     Delhi         40  Broken Glass 2018-12-01  [23, 47, 88]
# 7   France     Paris         88          Iron 2017-10-05      [67, 32]
#
#   Division_1 Division_2
# 0      div_a  sub_div_a
# 1      div_b  sub_div_b
# 2     no_div     no_div
# 3      div_d     no_div
# 4      div_b  sub_div_b
# 5      div_e     no_div
# 6      div_a  sub_div_a
# 7      div_b  sub_div_b

# %% [markdown]
# <br>
# <hr class="dotted">
# <br>

# %% [markdown]
# ### Handling non scalar values - <code>lists</code> to Rows

# %%
# We Also want to fix "SalesHistory" column, the values there have been added as lists
# We want to add rows (transactions) according to the list length
T = df['SalesHistory'].apply(pd.Series, dtype = int)
T.columns = ['SalesHistory_{}'.format(n) for n in range(1, len(T.columns)+1)]
df = df.drop('SalesHistory', axis=1).join(T)
df.fillna(0,inplace = True)
df
# Out:
#    Country      City  ProductId      Category       Date Division_1  \
# 0  Britian    London         40  Broken Glass 2018-12-01      div_a
# 1  Belgium  Brussels         77       Plastic 2017-10-05      div_b
# 2    Spain    Madrid         10     Hard Wood 2018-11-11     no_div
# 3     Prag  Budapest         10        Lether 2017-06-10      div_d
# 4  Belgium  Brussels         77       Plastic 2017-10-05      div_b
# 5   Israel     Haifa         88          Iron 2020-01-01      div_e
# 6    India     Delhi         40  Broken Glass 2018-12-01      div_a
# 7   France     Paris         88          Iron 2017-10-05      div_b
#
#   Division_2  SalesHistory_1  SalesHistory_2  SalesHistory_3
# 0  sub_div_a            23.0            47.0            88.0
# 1  sub_div_b            67.0            32.0             0.0
# 2     no_div             0.0             0.0             0.0
# 3     no_div            13.0             0.0             0.0
# 4  sub_div_b            67.0            32.0             0.0
# 5     no_div            15.0            80.0             0.0
# 6  sub_div_a            23.0            47.0            88.0
# 7  sub_div_b            67.0            32.0             0.0

# %%
df = df.melt(id_vars=["Country", "City", "ProductId", "Category","Date","Division_1","Division_2"], var_name='s',value_name = 'Sales')
df
# Out:
#     Country      City  ProductId      Category       Date Division_1  \
# 0   Britian    London         40  Broken Glass 2018-12-01      div_a
# 1   Belgium  Brussels         77       Plastic 2017-10-05      div_b
# 2     Spain    Madrid         10     Hard Wood 2018-11-11     no_div
# 3      Prag  Budapest         10        Lether 2017-06-10      div_d
# 4   Belgium  Brussels         77       Plastic 2017-10-05      div_b
# 5    Israel     Haifa         88          Iron 2020-01-01      div_e
# 6     India     Delhi         40  Broken Glass 2018-12-01      div_a
# 7    France     Paris         88          Iron 2017-10-05      div_b
# 8   Britian    London         40  Broken Glass 2018-12-01      div_a
# 9   Belgium  Brussels         77       Plastic 2017-10-05      div_b
# 10    Spain    Madrid         10     Hard Wood 2018-11-11     no_div
# 11     Prag  Budapest         10        Lether 2017-06-10      div_d
# 12  Belgium  Brussels         77       Plastic 2017-10-05      div_b
# 13   Israel     Haifa         88          Iron 2020-01-01      div_e
# 14    India     Delhi         40  Broken Glass 2018-12-01      div_a
# 15   France     Paris         88          Iron 2017-10-05      div_b
# 16  Britian    London         40  Broken Glass 2018-12-01      div_a
# 17  Belgium  Brussels         77       Plastic 2017-10-05      div_b
# 18    Spain    Madrid         10     Hard Wood 2018-11-11     no_div
# 19     Prag  Budapest         10        Lether 2017-06-10      div_d
# 20  Belgium  Brussels         77       Plastic 2017-10-05      div_b
# 21   Israel     Haifa         88          Iron 2020-01-01      div_e
# 22    India     Delhi         40  Broken Glass 2018-12-01      div_a
# 23   France     Paris         88          Iron 2017-10-05      div_b
#
#    Division_2               s  Sales
# 0   sub_div_a  SalesHistory_1   23.0
# 1   sub_div_b  SalesHistory_1   67.0
# 2      no_div  SalesHistory_1    0.0
# 3      no_div  SalesHistory_1   13.0
# 4   sub_div_b  SalesHistory_1   67.0
# 5      no_div  SalesHistory_1   15.0
# 6   sub_div_a  SalesHistory_1   23.0
# 7   sub_div_b  SalesHistory_1   67.0
# 8   sub_div_a  SalesHistory_2   47.0
# 9   sub_div_b  SalesHistory_2   32.0
# 10     no_div  SalesHistory_2    0.0
# 11     no_div  SalesHistory_2    0.0
# 12  sub_div_b  SalesHistory_2   32.0
# 13     no_div  SalesHistory_2   80.0
# 14  sub_div_a  SalesHistory_2   47.0
# 15  sub_div_b  SalesHistory_2   32.0
# 16  sub_div_a  SalesHistory_3   88.0
# 17  sub_div_b  SalesHistory_3    0.0
# 18     no_div  SalesHistory_3    0.0
# 19     no_div  SalesHistory_3    0.0
# 20  sub_div_b  SalesHistory_3    0.0
# 21     no_div  SalesHistory_3    0.0
# 22  sub_div_a  SalesHistory_3   88.0
# 23  sub_div_b  SalesHistory_3    0.0

# %%
#df  = df.drop('s',axis=1)
df.sort_values(by=['Country','City'],inplace=True)
df
# Out:
#     Country      City  ProductId      Category       Date Division_1  \
# 1   Belgium  Brussels         77       Plastic 2017-10-05      div_b
# 4   Belgium  Brussels         77       Plastic 2017-10-05      div_b
# 9   Belgium  Brussels         77       Plastic 2017-10-05      div_b
# 12  Belgium  Brussels         77       Plastic 2017-10-05      div_b
# 17  Belgium  Brussels         77       Plastic 2017-10-05      div_b
# 20  Belgium  Brussels         77       Plastic 2017-10-05      div_b
# 0   Britian    London         40  Broken Glass 2018-12-01      div_a
# 8   Britian    London         40  Broken Glass 2018-12-01      div_a
# 16  Britian    London         40  Broken Glass 2018-12-01      div_a
# 7    France     Paris         88          Iron 2017-10-05      div_b
# 15   France     Paris         88          Iron 2017-10-05      div_b
# 23   France     Paris         88          Iron 2017-10-05      div_b
# 6     India     Delhi         40  Broken Glass 2018-12-01      div_a
# 14    India     Delhi         40  Broken Glass 2018-12-01      div_a
# 22    India     Delhi         40  Broken Glass 2018-12-01      div_a
# 5    Israel     Haifa         88          Iron 2020-01-01      div_e
# 13   Israel     Haifa         88          Iron 2020-01-01      div_e
# 21   Israel     Haifa         88          Iron 2020-01-01      div_e
# 3      Prag  Budapest         10        Lether 2017-06-10      div_d
# 11     Prag  Budapest         10        Lether 2017-06-10      div_d
# 19     Prag  Budapest         10        Lether 2017-06-10      div_d
# 2     Spain    Madrid         10     Hard Wood 2018-11-11     no_div
# 10    Spain    Madrid         10     Hard Wood 2018-11-11     no_div
# 18    Spain    Madrid         10     Hard Wood 2018-11-11     no_div
#
#    Division_2               s  Sales
# 1   sub_div_b  SalesHistory_1   67.0
# 4   sub_div_b  SalesHistory_1   67.0
# 9   sub_div_b  SalesHistory_2   32.0
# 12  sub_div_b  SalesHistory_2   32.0
# 17  sub_div_b  SalesHistory_3    0.0
# 20  sub_div_b  SalesHistory_3    0.0
# 0   sub_div_a  SalesHistory_1   23.0
# 8   sub_div_a  SalesHistory_2   47.0
# 16  sub_div_a  SalesHistory_3   88.0
# 7   sub_div_b  SalesHistory_1   67.0
# 15  sub_div_b  SalesHistory_2   32.0
# 23  sub_div_b  SalesHistory_3    0.0
# 6   sub_div_a  SalesHistory_1   23.0
# 14  sub_div_a  SalesHistory_2   47.0
# 22  sub_div_a  SalesHistory_3   88.0
# 5      no_div  SalesHistory_1   15.0
# 13     no_div  SalesHistory_2   80.0
# 21     no_div  SalesHistory_3    0.0
# 3      no_div  SalesHistory_1   13.0
# 11     no_div  SalesHistory_2    0.0
# 19     no_div  SalesHistory_3    0.0
# 2      no_div  SalesHistory_1    0.0
# 10     no_div  SalesHistory_2    0.0
# 18     no_div  SalesHistory_3    0.0

# %%
df.reset_index(drop=True, inplace=True)
df
# Out:
#     Country      City  ProductId      Category       Date Division_1  \
# 0   Belgium  Brussels         77       Plastic 2017-10-05      div_b
# 1   Belgium  Brussels         77       Plastic 2017-10-05      div_b
# 2   Belgium  Brussels         77       Plastic 2017-10-05      div_b
# 3   Belgium  Brussels         77       Plastic 2017-10-05      div_b
# 4   Belgium  Brussels         77       Plastic 2017-10-05      div_b
# 5   Belgium  Brussels         77       Plastic 2017-10-05      div_b
# 6   Britian    London         40  Broken Glass 2018-12-01      div_a
# 7   Britian    London         40  Broken Glass 2018-12-01      div_a
# 8   Britian    London         40  Broken Glass 2018-12-01      div_a
# 9    France     Paris         88          Iron 2017-10-05      div_b
# 10   France     Paris         88          Iron 2017-10-05      div_b
# 11   France     Paris         88          Iron 2017-10-05      div_b
# 12    India     Delhi         40  Broken Glass 2018-12-01      div_a
# 13    India     Delhi         40  Broken Glass 2018-12-01      div_a
# 14    India     Delhi         40  Broken Glass 2018-12-01      div_a
# 15   Israel     Haifa         88          Iron 2020-01-01      div_e
# 16   Israel     Haifa         88          Iron 2020-01-01      div_e
# 17   Israel     Haifa         88          Iron 2020-01-01      div_e
# 18     Prag  Budapest         10        Lether 2017-06-10      div_d
# 19     Prag  Budapest         10        Lether 2017-06-10      div_d
# 20     Prag  Budapest         10        Lether 2017-06-10      div_d
# 21    Spain    Madrid         10     Hard Wood 2018-11-11     no_div
# 22    Spain    Madrid         10     Hard Wood 2018-11-11     no_div
# 23    Spain    Madrid         10     Hard Wood 2018-11-11     no_div
#
#    Division_2               s  Sales
# 0   sub_div_b  SalesHistory_1   67.0
# 1   sub_div_b  SalesHistory_1   67.0
# 2   sub_div_b  SalesHistory_2   32.0
# 3   sub_div_b  SalesHistory_2   32.0
# 4   sub_div_b  SalesHistory_3    0.0
# 5   sub_div_b  SalesHistory_3    0.0
# 6   sub_div_a  SalesHistory_1   23.0
# 7   sub_div_a  SalesHistory_2   47.0
# 8   sub_div_a  SalesHistory_3   88.0
# 9   sub_div_b  SalesHistory_1   67.0
# 10  sub_div_b  SalesHistory_2   32.0
# 11  sub_div_b  SalesHistory_3    0.0
# 12  sub_div_a  SalesHistory_1   23.0
# 13  sub_div_a  SalesHistory_2   47.0
# 14  sub_div_a  SalesHistory_3   88.0
# 15     no_div  SalesHistory_1   15.0
# 16     no_div  SalesHistory_2   80.0
# 17     no_div  SalesHistory_3    0.0
# 18     no_div  SalesHistory_1   13.0
# 19     no_div  SalesHistory_2    0.0
# 20     no_div  SalesHistory_3    0.0
# 21     no_div  SalesHistory_1    0.0
# 22     no_div  SalesHistory_2    0.0
# 23     no_div  SalesHistory_3    0.0

# %% [markdown]
# <br>
# <hr class="dotted">
# <br>

# %% [markdown]
# ### Handle Duplicates

# %% [markdown]
# last but not least<br>
# we have duplicated rows --> for example in "Belgium	Brussels" rows

# %%
# Removing Duplicates
# First we check if there are any..
df.duplicated()
# it means that the last row has a duplicate row
# Out:
# 0     False
# 1      True
# 2     False
# 3      True
# 4     False
# 5      True
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# 20    False
# 21    False
# 22    False
# 23    False
# dtype: bool

# %%
# Let's the duplictes
df[df.duplicated()]
# Out:
#    Country      City  ProductId Category       Date Division_1 Division_2  \
# 1  Belgium  Brussels         77  Plastic 2017-10-05      div_b  sub_div_b
# 3  Belgium  Brussels         77  Plastic 2017-10-05      div_b  sub_div_b
# 5  Belgium  Brussels         77  Plastic 2017-10-05      div_b  sub_div_b
#
#                 s  Sales
# 1  SalesHistory_1   67.0
# 3  SalesHistory_2   32.0
# 5  SalesHistory_3    0.0

# %%
# Duplicate Removed
df.drop_duplicates(inplace = True)
df
# Out:
#     Country      City  ProductId      Category       Date Division_1  \
# 0   Belgium  Brussels         77       Plastic 2017-10-05      div_b
# 2   Belgium  Brussels         77       Plastic 2017-10-05      div_b
# 4   Belgium  Brussels         77       Plastic 2017-10-05      div_b
# 6   Britian    London         40  Broken Glass 2018-12-01      div_a
# 7   Britian    London         40  Broken Glass 2018-12-01      div_a
# 8   Britian    London         40  Broken Glass 2018-12-01      div_a
# 9    France     Paris         88          Iron 2017-10-05      div_b
# 10   France     Paris         88          Iron 2017-10-05      div_b
# 11   France     Paris         88          Iron 2017-10-05      div_b
# 12    India     Delhi         40  Broken Glass 2018-12-01      div_a
# 13    India     Delhi         40  Broken Glass 2018-12-01      div_a
# 14    India     Delhi         40  Broken Glass 2018-12-01      div_a
# 15   Israel     Haifa         88          Iron 2020-01-01      div_e
# 16   Israel     Haifa         88          Iron 2020-01-01      div_e
# 17   Israel     Haifa         88          Iron 2020-01-01      div_e
# 18     Prag  Budapest         10        Lether 2017-06-10      div_d
# 19     Prag  Budapest         10        Lether 2017-06-10      div_d
# 20     Prag  Budapest         10        Lether 2017-06-10      div_d
# 21    Spain    Madrid         10     Hard Wood 2018-11-11     no_div
# 22    Spain    Madrid         10     Hard Wood 2018-11-11     no_div
# 23    Spain    Madrid         10     Hard Wood 2018-11-11     no_div
#
#    Division_2               s  Sales
# 0   sub_div_b  SalesHistory_1   67.0
# 2   sub_div_b  SalesHistory_2   32.0
# 4   sub_div_b  SalesHistory_3    0.0
# 6   sub_div_a  SalesHistory_1   23.0
# 7   sub_div_a  SalesHistory_2   47.0
# 8   sub_div_a  SalesHistory_3   88.0
# 9   sub_div_b  SalesHistory_1   67.0
# 10  sub_div_b  SalesHistory_2   32.0
# 11  sub_div_b  SalesHistory_3    0.0
# 12  sub_div_a  SalesHistory_1   23.0
# 13  sub_div_a  SalesHistory_2   47.0
# 14  sub_div_a  SalesHistory_3   88.0
# 15     no_div  SalesHistory_1   15.0
# 16     no_div  SalesHistory_2   80.0
# 17     no_div  SalesHistory_3    0.0
# 18     no_div  SalesHistory_1   13.0
# 19     no_div  SalesHistory_2    0.0
# 20     no_div  SalesHistory_3    0.0
# 21     no_div  SalesHistory_1    0.0
# 22     no_div  SalesHistory_2    0.0
# 23     no_div  SalesHistory_3    0.0

# %%
# last but not least
df.reset_index(drop=False, inplace=False)
df
# Out:
#     index  Country      City  ProductId      Category       Date Division_1  \
# 0       0  Belgium  Brussels         77       Plastic 2017-10-05      div_b
# 1       2  Belgium  Brussels         77       Plastic 2017-10-05      div_b
# 2       4  Belgium  Brussels         77       Plastic 2017-10-05      div_b
# 3       6  Britian    London         40  Broken Glass 2018-12-01      div_a
# 4       7  Britian    London         40  Broken Glass 2018-12-01      div_a
# 5       8  Britian    London         40  Broken Glass 2018-12-01      div_a
# 6       9   France     Paris         88          Iron 2017-10-05      div_b
# 7      10   France     Paris         88          Iron 2017-10-05      div_b
# 8      11   France     Paris         88          Iron 2017-10-05      div_b
# 9      12    India     Delhi         40  Broken Glass 2018-12-01      div_a
# 10     13    India     Delhi         40  Broken Glass 2018-12-01      div_a
# 11     14    India     Delhi         40  Broken Glass 2018-12-01      div_a
# 12     15   Israel     Haifa         88          Iron 2020-01-01      div_e
# 13     16   Israel     Haifa         88          Iron 2020-01-01      div_e
# 14     17   Israel     Haifa         88          Iron 2020-01-01      div_e
# 15     18     Prag  Budapest         10        Lether 2017-06-10      div_d
# 16     19     Prag  Budapest         10        Lether 2017-06-10      div_d
# 17     20     Prag  Budapest         10        Lether 2017-06-10      div_d
# 18     21    Spain    Madrid         10     Hard Wood 2018-11-11     no_div
# 19     22    Spain    Madrid         10     Hard Wood 2018-11-11     no_div
# 20     23    Spain    Madrid         10     Hard Wood 2018-11-11     no_div
#
#    Division_2               s  Sales
# 0   sub_div_b  SalesHistory_1   67.0
# 1   sub_div_b  SalesHistory_2   32.0
# 2   sub_div_b  SalesHistory_3    0.0
# 3   sub_div_a  SalesHistory_1   23.0
# 4   sub_div_a  SalesHistory_2   47.0
# 5   sub_div_a  SalesHistory_3   88.0
# 6   sub_div_b  SalesHistory_1   67.0
# 7   sub_div_b  SalesHistory_2   32.0
# 8   sub_div_b  SalesHistory_3    0.0
# 9   sub_div_a  SalesHistory_1   23.0
# 10  sub_div_a  SalesHistory_2   47.0
# 11  sub_div_a  SalesHistory_3   88.0
# 12     no_div  SalesHistory_1   15.0
# 13     no_div  SalesHistory_2   80.0
# 14     no_div  SalesHistory_3    0.0
# 15     no_div  SalesHistory_1   13.0
# 16     no_div  SalesHistory_2    0.0
# 17     no_div  SalesHistory_3    0.0
# 18     no_div  SalesHistory_1    0.0
# 19     no_div  SalesHistory_2    0.0
# 20     no_div  SalesHistory_3    0.0

# %% [markdown]
# <br>
# <hr class="dotted">
# <br>

# %% [markdown]
# ### Checking Data Type

# %%
df.dtypes
# Out:
# Country               object
# City                  object
# ProductId              int64
# Category              object
# Date          datetime64[ns]
# Division_1            object
# Division_2            object
# s                     object
# Sales                float64
# dtype: object

# %% [markdown]
# <br>
# <hr class="dotted">
# <br>

# %% [markdown]
# ### Compare with the original <code>df</code>

# %%
df
# Out:
#     Country      City  ProductId      Category       Date Division_1  \
# 0   Belgium  Brussels         77       Plastic 2017-10-05      div_b
# 1   Belgium  Brussels         77       Plastic 2017-10-05      div_b
# 2   Belgium  Brussels         77       Plastic 2017-10-05      div_b
# 3   Britian    London         40  Broken Glass 2018-12-01      div_a
# 4   Britian    London         40  Broken Glass 2018-12-01      div_a
# 5   Britian    London         40  Broken Glass 2018-12-01      div_a
# 6    France     Paris         88          Iron 2017-10-05      div_b
# 7    France     Paris         88          Iron 2017-10-05      div_b
# 8    France     Paris         88          Iron 2017-10-05      div_b
# 9     India     Delhi         40  Broken Glass 2018-12-01      div_a
# 10    India     Delhi         40  Broken Glass 2018-12-01      div_a
# 11    India     Delhi         40  Broken Glass 2018-12-01      div_a
# 12   Israel     Haifa         88          Iron 2020-01-01      div_e
# 13   Israel     Haifa         88          Iron 2020-01-01      div_e
# 14   Israel     Haifa         88          Iron 2020-01-01      div_e
# 15     Prag  Budapest         10        Lether 2017-06-10      div_d
# 16     Prag  Budapest         10        Lether 2017-06-10      div_d
# 17     Prag  Budapest         10        Lether 2017-06-10      div_d
# 18    Spain    Madrid         10     Hard Wood 2018-11-11     no_div
# 19    Spain    Madrid         10     Hard Wood 2018-11-11     no_div
# 20    Spain    Madrid         10     Hard Wood 2018-11-11     no_div
#
#    Division_2               s  Sales
# 0   sub_div_b  SalesHistory_1   67.0
# 1   sub_div_b  SalesHistory_2   32.0
# 2   sub_div_b  SalesHistory_3    0.0
# 3   sub_div_a  SalesHistory_1   23.0
# 4   sub_div_a  SalesHistory_2   47.0
# 5   sub_div_a  SalesHistory_3   88.0
# 6   sub_div_b  SalesHistory_1   67.0
# 7   sub_div_b  SalesHistory_2   32.0
# 8   sub_div_b  SalesHistory_3    0.0
# 9   sub_div_a  SalesHistory_1   23.0
# 10  sub_div_a  SalesHistory_2   47.0
# 11  sub_div_a  SalesHistory_3   88.0
# 12     no_div  SalesHistory_1   15.0
# 13     no_div  SalesHistory_2   80.0
# 14     no_div  SalesHistory_3    0.0
# 15     no_div  SalesHistory_1   13.0
# 16     no_div  SalesHistory_2    0.0
# 17     no_div  SalesHistory_3    0.0
# 18     no_div  SalesHistory_1    0.0
# 19     no_div  SalesHistory_2    0.0
# 20     no_div  SalesHistory_3    0.0

# %%
# Finaly - Let's compare the new "df" to the old one
df_Old = pd.DataFrame(dic)
df_Old
# Out:
#             Country  ProductId  SalesHistory          Category        Date  \
# 0    LoNDon_britian       35.0  [23, 47, 88]  (Broken Glass. )  2018/12/01
# 1  Brussels_BelgIUm    77000.0      [67, 32]       98. Plastic  2017/10/05
# 2      MAdrid_spAIN        NaN            []  <Hard Wood> (45)  2018/11/11
# 3    londON_briTiAn       53.0  [24, 43, 87]          STEEL(&)        None
# 4     Budapest_PraG        NaN          [13]          "Lether"  2017/06/10
# 5  Brussels_BelgIUm    77000.0      [67, 32]       98. Plastic  2017/10/05
#
#              Division
# 0  [div_a, sub_div_a]
# 1  [div_b, sub_div_b]
# 2                  []
# 3  [div_c, sub_div_c]
# 4             [div_d]
# 5  [div_b, sub_div_b]
