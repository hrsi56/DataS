# %% [markdown]
# # Matplotlib
#
# ## Questions

# %% [markdown]
# © Advanced Analytics, Amir Ben Haim, 2024

# %%
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ## Exercise 1:
# Create a simple line plot for the equation
# <br>`x = np.linspace(0, 10, 100)`
# <br>`y=x`.

# %%
x = np.linspace(0, 10, 100)
y=x
plt.plot(x,y)
plt.show()

# %% [markdown]
# ## Exercise 2:
# Add title "y = x graph" to the plot.

# %%
x = np.linspace(0, 10, 100)
y=x
plt.plot(x,y)
plt.title('y = x graph')
plt.show()

# %% [markdown]
# ## Exercise 3:
# Add labels "x" and "y" to the axes.

# %%
x = np.linspace(0, 10, 100)
y=x
plt.plot(x,y)
plt.title('y = x graph')
plt.ylabel('y')
plt.xlabel('x')
plt.show()

# %% [markdown]
# ## Exercise 4:
# Plot the following functions on the same graph:
# <br>`y = x`, `y = x^2`, and `y = x^3`
# <br>for x ranging from 0 to 10 (`x = np.linspace(0, 10, 400)`).<br>
# Use different styles for each plot.

# %%
x = np.linspace(0, 10, 400)
y=x
y2= x**3
y3 = x**2
plt.plot(x,y,'b',x,y2,'g',x,y3,'y')
plt.title('y graph')
plt.ylabel('y')
plt.xlabel('x')
plt.show()

# %% [markdown]
# ## Exercise 5:
# Create a plot for the function
# <br>`x = np.linspace(-10, 10, 400)`
# <br>`y = x^2`
# <br>and set the limit of x axis from -10 to 10 and y axis from -10 to 100.

# %%
x = np.linspace(-10, 10, 400)
y = x**2
plt.plot(x,y,'b')
plt.title('y = x^2 graph')
plt.ylabel('y')
plt.xlabel('x')
plt.show()

# %% [markdown]
# ## Exercise 6:
# Add grid to the plot created in previous exercise.

# %%
x = np.linspace(-10, 10, 400)
y = x**2
plt.plot(x,y,'b')
plt.title('y = x^2 graph')
plt.grid()
plt.ylabel('y')
plt.xlabel('x')
plt.show()

# %% [markdown]
#  ## Exercise 7:
# Plot a sin function from 0 to 2*pi.
# <br>
# `x = np.linspace(0, 2 * np.pi, 100)`
# <br>
# `y = np.sin(x)`

# %%
x = np.linspace(0, 2 * np.pi, 100)
y = np.sin(x)
plt.plot(x,y,'b')
plt.title('y = sin(x) graph')
plt.grid()
plt.ylabel('y')
plt.xlabel('x')
plt.show()

# %% [markdown]
# ## Exercise 8:
# Plot both sin and cosine functions on the same graph from 0 to 2*pi.
# <br>
# Add a legend to the plot.
# <br>
# `x = np.linspace(0, 2 * np.pi, 100)`
# <br>
# `y_sin = np.sin(x)`
# <br>
# `y_cos = np.cos(x)`

# %%
x = np.linspace(0, 2 * np.pi, 100)
y_sin = np.sin(x)
y_cos = np.cos(x)
plt.plot(x,y_sin,'b',x,y_cos,'orange')
plt.title('y_sin = sin(x) graph \ny_cos = cos(x) graph')
plt.grid()
plt.ylabel('y')
plt.xlabel('x')
plt.show()

# %% [markdown]
# ## Exercise 9:
# Create a figure with 2 subplots.
# <br>Plot a sin function on the first and a cosine function on the second subplot.
# <br>
# `x = np.linspace(0, 2 * np.pi, 100)`
# <br>
# `y_sin = np.sin(x)`
# <br>
# `y_cos = np.cos(x)`

# %%
x = np.linspace(0, 2 * np.pi, 100)
y_sin = np.sin(x)
y_cos = np.cos(x)

plt.figure()

plt.subplot(2,1,1)
plt.plot(x,y_sin,'b')
plt.title('y_sin = sin(x) graph')
plt.grid()
plt.ylabel('y')

plt.subplot(2,1,2)
plt.plot(x,y_cos,'orange')
plt.title('y_sin = sin(x) graph')
plt.grid()
plt.ylabel('y')
plt.xlabel('x')

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Exercise 10:
# Create a scatter plot with 100 random data points.
# <br>
# `x = np.random.rand(100)`
# <br>
# `y = np.random.rand(100)`

# %%
x = np.random.rand(100)
y = np.random.rand(100)

plt.scatter(x,y)
plt.show()

# %% [markdown]
# ## Exercise 11:
# Create a scatter plot with 100 random data points.
# <br>
# Use red color for points where x value is less than 0.5 and blue for others.
# <br>
# `x = np.random.rand(100)`
# <br>
# `y = np.random.rand(100)`

# %%
x = np.random.rand(100)
y = np.random.rand(100)
plt.scatter(x[x<0.5],y[x<0.5],c='r')
plt.scatter(x[x>0.5],y[x>0.5],c='b')
plt.show()

# %% [markdown]
# ## Exercise 12:
# Plot a line chart and a scatter plot on the same graph.
# <br>
# For the line chart, plot:
#
# `x_line = np.linspace(0, 1, 100)`<br>
# `y_line = x^2`
# <br>
# <br>
# `x_scat = np.random.rand(100)`
# <br>
# `y_scat = np.random.rand(100)`
#
# <br>
# and for the scatter plot, use 100 random points.

# %%
x_line = np.linspace(0, 1, 100)
y_line = x_line**2

plt.plot(x_line,y_line,'r')


x = np.random.rand(100)
y = np.random.rand(100)

plt.scatter(x[y>x**2],y[y>x**2],c='b')
plt.scatter(x[y<x**2],y[y<x**2],c='r')

plt.title('line and scatter plot')
plt.ylabel('y')
plt.xlabel('x')
plt.show()

# %% [markdown]
# ## Exercise 13:
# Create a bar plot representing the following data:
# <br>`{'Apples': 30, 'Bananas': 15, 'Cherries': 55, 'Dates': 20}`.

# %%
dic = {'Apples': 30, 'Bananas': 15, 'Cherries': 55, 'Dates': 20}
plt.bar(dic.keys(),dic.values())
plt.show()

# %% [markdown]
# ## Exercise 14:
# Plot a bar graph representing the popularity of programming languages. Use the following data:
#
# `Languages = ['Python', 'SQL', 'Java', 'C++', 'JavaScript']`
# <br>
# `Popularity = [56, 39, 34, 34, 29]`

# %%
Languages = ['Python', 'SQL', 'Java', 'C++', 'JavaScript']
Popularity = [56, 39, 34, 34, 29]
plt.bar(Languages,Popularity)
plt.show()

# %% [markdown]
# ## Exercise 15:
# Create a histogram of a set of normally distributed random data.
# <br>`data = np.random.randn(1000)`

# %%
data = np.random.randn(1000)
plt.hist(data,100)
plt.show()

# %% [markdown]
# ## Exercise 16:
# Plot a histogram for 3 different data sets.
# <br>`data1 = np.random.normal(0, 0.8, 1000)`
# <br>`data2 = np.random.normal(-2, 1, 1000)`
# <br>`data3 = np.random.normal(3, 2, 1000)`

# %%
import numpy as np
import matplotlib.pyplot as plt

# Generate data
data1 = np.random.normal(0, 0.8, 1000)
data2 = np.random.normal(-2, 1, 1000)
data3 = np.random.normal(3, 2, 1000)

# Define consistent bins
bins = 100  # Number of bins

# Compute histogram data for consistent y-axis
_, bin_edges = np.histogram(np.concatenate([data1, data2, data3]), bins=bins)
counts1, _ = np.histogram(data1, bins=bin_edges)
counts2, _ = np.histogram(data2, bins=bin_edges)
counts3, _ = np.histogram(data3, bins=bin_edges)
counts_combined, _ = np.histogram(np.concatenate([data1, data2, data3]), bins=bin_edges)

# Find the maximum y-limit across all histograms
max_y = max(counts1.max(), counts2.max(), counts3.max(), counts_combined.max())

# Plot separate histograms
plt.figure(figsize=(10, 6))
plt.hist(data1, bins=bin_edges, alpha=0.5, label='Data 1', color='blue', edgecolor='black')
plt.hist(data2, bins=bin_edges, alpha=0.5, label='Data 2', color='green', edgecolor='black')
plt.hist(data3, bins=bin_edges, alpha=0.5, label='Data 3', color='orange', edgecolor='black')
plt.ylim(0, max_y + 10)  # Set consistent y-axis limit

plt.title('Separate Histograms with Consistent Binning and Y-Axis', fontsize=14)
plt.xlabel('Value', fontsize=12)
plt.ylabel('Frequency', fontsize=12)
plt.legend(fontsize=10)
plt.grid(alpha=0.3, linestyle='--')
plt.show()

# Plot combined histogram
plt.figure(figsize=(10, 6))
plt.hist([data1, data2, data3], bins=bin_edges, alpha=0.7, label=['Data 1', 'Data 2', 'Data 3'], edgecolor='black')
plt.ylim(0, max_y + 10)  # Set consistent y-axis limit

plt.title('Combined Histogram with Consistent Binning and Y-Axis', fontsize=14)
plt.xlabel('Value', fontsize=12)
plt.ylabel('Frequency', fontsize=12)
plt.legend(fontsize=10)
plt.grid(alpha=0.3, linestyle='--')
plt.show()

# %%
data1 = np.random.normal(0, 0.8, 1000)
data2 = np.random.normal(-2, 1, 1000)
data3 = np.random.normal(3, 2, 1000)

plt.hist(data1,100,alpha=0.5)
plt.hist(data2,100,alpha=0.5)
plt.hist(data3,100,alpha=0.5)

plt.show()

# %% [markdown]
# ## Exercise 17:
# Create a pie chart representing the following data:
# <br>`{'Apples': 30, 'Bananas': 15, 'Cherries': 55, 'Grapes': 20}`.

# %%
d={'Apples': 30, 'Bananas': 15, 'Cherries': 55, 'Grapes': 20}

plt.pie(d.values(), labels=d.keys())
plt.show()

# %% [markdown]
# ## Exercise 18:
# Add the pie the percentage for each fruite

# %%
d={'Apples': 30, 'Bananas': 15, 'Cherries': 55, 'Grapes': 20}

plt.pie(d.values(), labels=d.keys(),autopct='%.1f%%')
plt.show()
